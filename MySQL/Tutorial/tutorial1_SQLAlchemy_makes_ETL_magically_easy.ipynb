# %%
# ref: SQLAlchemy makes ETL magically easy
# https://www.freecodecamp.org/news/sqlalchemy-makes-etl-magically-easy-ab2bd0df928/

# %%
import sqlalchemy
sqlalchemy.__version__
# Out:
# '1.4.15'

# %%
import pandas as pd

# %% [markdown]
# # Defining a schema
# A database schema defines the structure of a database system, in terms of tables, columns, fields, and the relationships between them. Schemas can be defined in raw SQL, or through the use of SQLAlchemy’s ORM feature.
#
# Below is an example showing how to define a schema of two tables for an imaginary blogging platform. One is a table of users, and the other is a table of posts uploaded.

# %% [markdown]
# Note:
# Here Users.DOB is set to DateTime type, which should be Date instead. I define the DateTime type on purpose to inspect a phenomenon later: what happen if we feed in database with a "wrong" type?

# %%
from sqlalchemy import *
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
from sqlalchemy.sql import *
from sqlalchemy.orm import relationship

engine = create_engine('sqlite://') #use sqlite in memory
Base = declarative_base()

class Users(Base):
    __tablename__ = "users"
    UserId = Column(Integer, primary_key=True)
    Title = Column(String)
    FirstName = Column(String)
    LastName = Column(String)
    Email = Column(String)
    Username = Column(String)
    DOB = Column(DateTime)

class Uploads(Base):
    __tablename__ = "uploads"
    UploadId = Column(Integer, primary_key=True)
    UserId = Column(Integer, ForeignKey('users.UserId'))
    Title = Column(String)
    Body = Column(String)
    Timestamp = Column(DateTime)    
#     user = relationship("Users", back_populates = "uploads")    
# relationships: https://www.tutorialspoint.com/sqlalchemy/sqlalchemy_orm_building_relationship.htm
# Users.uploads = relationship("Uploads", order_by = Uploads.UserId, back_populates = "users")


Users.__table__.create(bind=engine, checkfirst=True)
Uploads.__table__.create(bind=engine, checkfirst=True)

# %% [markdown]
# First, import everything you need from SQLAlchemy. Then, use create_engine(connection_string) to connect to your database. The exact connection string will depend on the version of SQL you are working with. This example uses a relative path to the SQLite database created earlier.
#
# Next, start defining your table classes. The first one in the example is Users. Each column in this table is defined as a class variable using SQLAlchemy’s Column(type), where type is a data type (such as Integer, String, DateTime and so on). Use primary_key=True to denote columns which will be used as primary keys.
#
# The next table defined here is Uploads. It’s very much the same idea — each column is defined as before.
#
# The final two lines actually create the tables. The checkfirst=True parameter ensures that new tables are only created if they do not currently exist in the database.

# %%
Users.__table__
# Out:
# Table('users', MetaData(), Column('UserId', Integer(), table=<users>, primary_key=True, nullable=False), Column('Title', String(), table=<users>), Column('FirstName', String(), table=<users>), Column('LastName', String(), table=<users>), Column('Email', String(), table=<users>), Column('Username', String(), table=<users>), Column('DOB', DateTime(), table=<users>), schema=None)

# %%
Uploads.__table__
# Out:
# Table('uploads', MetaData(), Column('UploadId', Integer(), table=<uploads>, primary_key=True, nullable=False), Column('UserId', Integer(), ForeignKey('users.UserId'), table=<uploads>), Column('Title', String(), table=<uploads>), Column('Body', String(), table=<uploads>), Column('Timestamp', DateTime(), table=<uploads>), schema=None)

# %% [markdown]
# # Reflect the schema
# Here we would like to check if the schema is successively created in the database. In order to reflect a database, instead of using the declarative_base we’ve been using with the ORM so far, we’re going to use the automap_base.
#
# Or, just query the database (sql methods)

# %%
from sqlalchemy.ext.automap import automap_base

Base_reflect = automap_base()
Base_reflect.prepare(engine, reflect=True)
Base_reflect.classes.keys()
# Out:
# ['uploads', 'users']

# %%
# the uploads table (class)
uploads_reflect = Base_reflect.classes.uploads
uploads_reflect.__table__

# the users table (class)
users_reflect = Base_reflect.classes.users
users_reflect.__table__

# columns in the uploads table (class)
[col for col in uploads_reflect.__table__.columns]

# columns in the uploads table (class)
[col for col in users_reflect.__table__.columns]

# foreign keys
print(users_reflect.__table__.foreign_keys, "\n")
print(uploads_reflect.__table__.foreign_keys, "\n")

# all the constraints (it is a set)
uploads_reflect.__table__.constraints
type(uploads_reflect.__table__.constraints)

for constr in list(uploads_reflect.__table__.constraints):
    print(constr,"\n")
# Out:
# set()
#
# {ForeignKey('users.UserId')}
#
# ForeignKeyConstraint(<sqlalchemy.sql.base.DedupeColumnCollection object at 0x7f9db30f6860>, None, link_to_name=True, table=Table('uploads', MetaData(), Column('UploadId', INTEGER(), table=<uploads>, primary_key=True, nullable=False), Column('UserId', INTEGER(), ForeignKey('users.UserId'), table=<uploads>), Column('Title', VARCHAR(), table=<uploads>), Column('Body', VARCHAR(), table=<uploads>), Column('Timestamp', DATETIME(), table=<uploads>), schema=None))
#
# PrimaryKeyConstraint(Column('UploadId', INTEGER(), table=<uploads>, primary_key=True, nullable=False))

# %%
# ultimate method (in sqlite)
pd.read_sql("select * from sqlite_schema", con=engine)
pd.read_sql("select * from sqlite_schema", con=engine).sql.apply(lambda x: print(x))
# Out:
# CREATE TABLE users (
# 	"UserId" INTEGER NOT NULL,
# 	"Title" VARCHAR,
# 	"FirstName" VARCHAR,
# 	"LastName" VARCHAR,
# 	"Email" VARCHAR,
# 	"Username" VARCHAR,
# 	"DOB" DATETIME,
# 	PRIMARY KEY ("UserId")
# )
# CREATE TABLE uploads (
# 	"UploadId" INTEGER NOT NULL,
# 	"UserId" INTEGER,
# 	"Title" VARCHAR,
# 	"Body" VARCHAR,
# 	"Timestamp" DATETIME,
# 	PRIMARY KEY ("UploadId"),
# 	FOREIGN KEY("UserId") REFERENCES users ("UserId")
# )
# 0    None
# 1    None
# Name: sql, dtype: object

# %% [markdown]
# # Extract
# Once the schema has been defined, the next task is to extract the raw data from its source. The exact details can vary wildly from case to case, depending on how the raw data is provided. Maybe your app calls an in-house or third-party API, or perhaps you need to read data logged in a CSV file.
#
# The example below uses two APIs to simulate data for the fictional blogging platform described above. The Users table will be populated with profiles randomly generated at randomuser.me, and the Uploads table will contain lorem ipsum-inspired data courtesy of JSONPlaceholder.
#
# Python’s Requests module can be used to call these APIs, as shown below:

# %%
import requests

url = 'https://randomuser.me/api/?results=10'
users_json = requests.get(url).json()
url2 = 'https://jsonplaceholder.typicode.com/posts/'
uploads_json = requests.get(url2).json()

# %%
## Add this to the first block in your note book to display json
# another option: 
import uuid
from IPython.core.display import display, HTML

import json

class RenderJSON(object):
    def __init__(self, json_data):
        if isinstance(json_data, dict):
            self.json_str = json.dumps(json_data)
        else:
            self.json_str = json_data
        self.uuid = str(uuid.uuid4())
        # This line is missed out in most of the versions of this script across the web, it is essential for this to work interleaved with print statements
#         self._ipython_display_()
        
    def _ipython_display_(self):
        display(HTML('<div id="{}" style="height: auto; width:100%;"></div>'.format(self.uuid)))
        display(HTML("""<script>
        require(["https://rawgit.com/caldwell/renderjson/master/renderjson.js"], function() {
          renderjson.set_show_to_level(1)
          document.getElementById('%s').appendChild(renderjson(%s))
        });</script>
        """ % (self.uuid, self.json_str)))

# %%
# RenderJSON(users_json)

# %%
# RenderJSON(uploads_json)

# %%
import pandas as pd
df_user = pd.json_normalize(users_json.get("results"))
df_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   gender                          10 non-null     object
#  1   email                           10 non-null     object
#  2   phone                           10 non-null     object
#  3   cell                            10 non-null     object
#  4   nat                             10 non-null     object
#  5   name.title                      10 non-null     object
#  6   name.first                      10 non-null     object
#  7   name.last                       10 non-null     object
#  8   location.street.number          10 non-null     int64
#  9   location.street.name            10 non-null     object
#  10  location.city                   10 non-null     object
#  11  location.state                  10 non-null     object
#  12  location.country                10 non-null     object
#  13  location.postcode               10 non-null     object
#  14  location.coordinates.latitude   10 non-null     object
#  15  location.coordinates.longitude  10 non-null     object
#  16  location.timezone.offset        10 non-null     object
#  17  location.timezone.description   10 non-null     object
#  18  login.uuid                      10 non-null     object
#  19  login.username                  10 non-null     object
#  20  login.password                  10 non-null     object
#  21  login.salt                      10 non-null     object
#  22  login.md5                       10 non-null     object
#  23  login.sha1                      10 non-null     object
#  24  login.sha256                    10 non-null     object
#  25  dob.date                        10 non-null     object
#  26  dob.age                         10 non-null     int64
#  27  registered.date                 10 non-null     object
#  28  registered.age                  10 non-null     int64
#  29  id.name                         10 non-null     object
#  30  id.value                        8 non-null      object
#  31  picture.large                   10 non-null     object
#  32  picture.medium                  10 non-null     object
#  33  picture.thumbnail               10 non-null     object
# dtypes: int64(3), object(31)
# memory usage: 2.8+ KB

# %%
# df_user[["id.value"]]
df_user.head()
# Out:
#    gender                        email           phone            cell nat  \
# 0    male  curtis.richards@example.com    021-148-4908    081-907-1839  IE
# 1    male   chris.ferguson@example.com    061-228-6605    081-319-6477  IE
# 2    male      anthony.kim@example.com  (674)-645-1776  (418)-236-3460  US
# 3  female  nicoline.larsen@example.com        18372514        06955280  DK
# 4    male     lucas.martin@example.com    378-134-1207    110-471-6965  CA
#
#   name.title name.first name.last  location.street.number  \
# 0         Mr     Curtis  Richards                    5923
# 1         Mr      Chris  Ferguson                    4987
# 2         Mr    Anthony       Kim                    5342
# 3         Ms   Nicoline    Larsen                    4305
# 4         Mr      Lucas    Martin                    8470
#
#   location.street.name  ...  \
# 0     O'Connell Avenue  ...
# 1           North Road  ...
# 2          Prospect Rd  ...
# 3             Bakkevej  ...
# 4            Alfred St  ...
#
#                                         login.sha256  \
# 0  fdc693897d46b98974747047e7016556a09c6dcdb9eeeb...
# 1  26962adf2750c6858892480ac30c44229696e2a1e24fd7...
# 2  436b5e7901c3495e689419138e0dda2953eb9c8826275f...
# 3  c32623cc5cdc08ecd2f723800463672221b27784477f0c...
# 4  9d1a6f4c042a7ff3fbf09ca60082a7b669960acb40a381...
#
#                    dob.date dob.age           registered.date registered.age  \
# 0  1984-09-02T05:55:10.713Z      37  2009-08-01T06:20:32.997Z             12
# 1  1992-08-20T16:40:46.834Z      29  2004-02-16T19:51:38.913Z             17
# 2  1957-08-28T15:12:29.264Z      64  2007-06-03T03:40:59.098Z             14
# 3  1958-10-25T11:23:24.901Z      63  2019-08-18T13:22:12.166Z              2
# 4  1961-08-14T02:56:45.946Z      60  2011-06-01T09:17:15.794Z             10
#
#   id.name     id.value                                     picture.large  \
# 0     PPS     4254991T    https://randomuser.me/api/portraits/men/75.jpg
# 1     PPS     9890280T    https://randomuser.me/api/portraits/men/99.jpg
# 2     SSN  857-32-0326    https://randomuser.me/api/portraits/men/50.jpg
# 3     CPR  251058-2370  https://randomuser.me/api/portraits/women/42.jpg
# 4                 None    https://randomuser.me/api/portraits/men/59.jpg
#
#                                       picture.medium  \
# 0  https://randomuser.me/api/portraits/med/men/75...
# 1  https://randomuser.me/api/portraits/med/men/99...
# 2  https://randomuser.me/api/portraits/med/men/50...
# 3  https://randomuser.me/api/portraits/med/women/...
# 4  https://randomuser.me/api/portraits/med/men/59...
#
#                                    picture.thumbnail
# 0  https://randomuser.me/api/portraits/thumb/men/...
# 1  https://randomuser.me/api/portraits/thumb/men/...
# 2  https://randomuser.me/api/portraits/thumb/men/...
# 3  https://randomuser.me/api/portraits/thumb/wome...
# 4  https://randomuser.me/api/portraits/thumb/men/...
#
# [5 rows x 34 columns]

# %%
pd.json_normalize(uploads_json)
# Out:
#     userId   id                                              title  \
# 0        1    1  sunt aut facere repellat provident occaecati e...
# 1        1    2                                       qui est esse
# 2        1    3  ea molestias quasi exercitationem repellat qui...
# 3        1    4                               eum et est occaecati
# 4        1    5                                 nesciunt quas odio
# ..     ...  ...                                                ...
# 95      10   96  quaerat velit veniam amet cupiditate aut numqu...
# 96      10   97         quas fugiat ut perspiciatis vero provident
# 97      10   98                        laboriosam dolor voluptates
# 98      10   99  temporibus sit alias delectus eligendi possimu...
# 99      10  100              at nam consequatur ea labore ea harum
#
#                                                  body
# 0   quia et suscipit\nsuscipit recusandae consequu...
# 1   est rerum tempore vitae\nsequi sint nihil repr...
# 2   et iusto sed quo iure\nvoluptatem occaecati om...
# 3   ullam et saepe reiciendis voluptatem adipisci\...
# 4   repudiandae veniam quaerat sunt sed\nalias aut...
# ..                                                ...
# 95  in non odio excepturi sint eum\nlabore volupta...
# 96  eum non blanditiis soluta porro quibusdam volu...
# 97  doloremque ex facilis sit sint culpa\nsoluta a...
# 98  quo deleniti praesentium dicta non quod\naut e...
# 99  cupiditate quo est a modi nesciunt soluta\nips...
#
# [100 rows x 4 columns]

# %% [markdown]
# The data is currently held in two objects (users_json and uploads_json) in JSON format. The next step will be to transform and load this data into the tables defined earlier.

# %% [markdown]
# # Transform
# Before the data can be loaded into the database, it is important to ensure that it is in the correct format. The JSON objects created in the code above are nested, and contain more data than is required for the tables defined.
#
# An important intermediary step is to transform the data from its current nested JSON format to a flat format that can be safely written to the database without error.
#
# For the example running through this article, the data are relatively simple, and won’t need much transformation. The code below creates two lists, users and uploads, which will be used in the final step:

# %%
# detour: date time parsing
# What is this date format? 2011-08-12T20:17:46.384Z
# ANS: ISO 8061 (A datetime format many open API adopt)

import dateutil.parser
date_str = "2011-08-12T20:17:46.384Z"
date_str = "2011-08-12T20:17:46.384+8:00"
print(type(dateutil.parser.parse(date_str)))
date_time = dateutil.parser.parse(date_str)
print(date_time.date(),"\n",
      date_time.time(),"\n",
      date_time.timetz())
# Out:
# <class 'datetime.datetime'>
# 2011-08-12
#  20:17:46.384000
#  20:17:46.384000+08:00

# %%
# construct users-list uplods-list
# (Note: Here is the original users-list and uplods-list construnctor. 
# Later, we will present a more concise version using df.to_list("records") method)
from datetime import datetime, timedelta
from random import randint


users, uploads = [], []

for i, result in enumerate(users_json['results']):
    row = {}
    row['UserId'] = i
    row['Title'] = result['name']['title']
    row['FirstName'] = result['name']['first']
    row['LastName'] = result['name']['last']
    row['Email'] = result['email']
    row['Username'] = result['login']['username']
#     dob = datetime.strptime(result['dob']['date'],'%Y-%m-%d %H:%M:%S')    
    dob = dateutil.parser.parse(result['dob']['date'])
    row['DOB'] = dob.date()
    
    users.append(row)
    
for result in uploads_json:
    row = {}
    row['UploadId'] = result['id']
    row['UserId'] = result['userId']
    row['Title'] = result['title']
    row['Body'] = result['body']
    delta = timedelta(seconds=randint(1,86400))
    row['Timestamp'] = datetime.now() - delta
    
    uploads.append(row)

# %%
# date time type
print("users.DOB: ", type(users[0].get("DOB")))
print("uploads.Timestamp: ", type(uploads[0].get("Timestamp")))
# Out:
# users.DOB:  <class 'datetime.date'>
# uploads.Timestamp:  <class 'datetime.datetime'>

# %%
pd.DataFrame(users)
# Out:
#    UserId Title FirstName  LastName                         Email  \
# 0       0    Mr    Curtis  Richards   curtis.richards@example.com
# 1       1    Mr     Chris  Ferguson    chris.ferguson@example.com
# 2       2    Mr   Anthony       Kim       anthony.kim@example.com
# 3       3    Ms  Nicoline    Larsen   nicoline.larsen@example.com
# 4       4    Mr     Lucas    Martin      lucas.martin@example.com
# 5       5    Mr     Craig   Coleman     craig.coleman@example.com
# 6       6    Mr  Muhammad   Lødemel  muhammad.lodemel@example.com
# 7       7  Miss     Ethel      Diaz        ethel.diaz@example.com
# 8       8    Ms    Eloane    Berger     eloane.berger@example.com
# 9       9    Mr    Justin       Roy        justin.roy@example.com
#
#              Username         DOB
# 0     smallostrich277  1984-09-02
# 1    silverostrich434  1992-08-20
# 2     redbutterfly849  1957-08-28
# 3         lazywolf848  1958-10-25
# 4     angrymeercat769  1961-08-14
# 5    purpleostrich376  1992-06-04
# 6  ticklishmeercat301  1963-09-23
# 7    ticklishpanda585  1995-05-29
# 8     heavygorilla337  1975-12-16
# 9     whitepeacock882  1981-07-25

# %%
pd.DataFrame(uploads)
# Out:
#     UploadId  UserId                                              Title  \
# 0          1       1  sunt aut facere repellat provident occaecati e...
# 1          2       1                                       qui est esse
# 2          3       1  ea molestias quasi exercitationem repellat qui...
# 3          4       1                               eum et est occaecati
# 4          5       1                                 nesciunt quas odio
# ..       ...     ...                                                ...
# 95        96      10  quaerat velit veniam amet cupiditate aut numqu...
# 96        97      10         quas fugiat ut perspiciatis vero provident
# 97        98      10                        laboriosam dolor voluptates
# 98        99      10  temporibus sit alias delectus eligendi possimu...
# 99       100      10              at nam consequatur ea labore ea harum
#
#                                                  Body  \
# 0   quia et suscipit\nsuscipit recusandae consequu...
# 1   est rerum tempore vitae\nsequi sint nihil repr...
# 2   et iusto sed quo iure\nvoluptatem occaecati om...
# 3   ullam et saepe reiciendis voluptatem adipisci\...
# 4   repudiandae veniam quaerat sunt sed\nalias aut...
# ..                                                ...
# 95  in non odio excepturi sint eum\nlabore volupta...
# 96  eum non blanditiis soluta porro quibusdam volu...
# 97  doloremque ex facilis sit sint culpa\nsoluta a...
# 98  quo deleniti praesentium dicta non quod\naut e...
# 99  cupiditate quo est a modi nesciunt soluta\nips...
#
#                     Timestamp
# 0  2021-06-07 23:08:03.031695
# 1  2021-06-07 21:02:10.031700
# 2  2021-06-08 05:04:49.031702
# 3  2021-06-08 16:20:04.031704
# 4  2021-06-07 20:42:02.031706
# ..                        ...
# 95 2021-06-08 00:01:38.031951
# 96 2021-06-07 21:25:40.031953
# 97 2021-06-08 02:38:59.031954
# 98 2021-06-08 06:44:09.031956
# 99 2021-06-08 01:21:51.031958
#
# [100 rows x 5 columns]

# %% [markdown]
# The main step here is to iterate through the JSON objects created before. For each result, create a new Python dictionary object with keys corresponding to each column defined for the relevant table in the schema. This ensures that the data is no longer nested, and keeps only the data needed for the tables.
#
# The other step is to use Python’s datetime module to manipulate dates, and transform them into DateTime type objects that can be written to the database. For the sake of this example, random DateTime objects are generated using the timedelta() method from Python’s DateTime module.
#
# Each created dictionary is appended to a list, which will be used in the final step of the pipeline.

# %% [markdown]
# # Load
# Finally, the data is in a form that can be loaded into the database. SQLAlchemy makes this step straightforward through its Session API.
#
# The Session API acts a bit like a middleman, or “holding zone,” for Python objects you have either loaded from or associated with the database. These objects can be manipulated within the session before being committed to the database.
#
# The code below creates a new session object, adds rows to it, then merges and commits them to the database:

# %%
# using sqlachemy ORM and try/except style:
# considr some modification to next code blocks.
Session = sessionmaker(bind=engine)
session = Session()

try:
    for user in users:
        row = Users(**user)
        session.add(row)

    for upload in uploads:
        row = Uploads(**upload)
        session.add(row)

    session.commit()
except Exception as e: 
    print(e)
finally:
    session.close()

# %% [markdown]
# The sessionmaker factory is used to generate newly-configured Session classes. Session is an everyday Python class that is instantiated on the second line as session.
#
# Next up are two loops which iterate through the users and uploads lists created earlier. The elements of these lists are dictionary objects whose keys correspond to the columns given in the Users and Uploads classes defined previously.
#
# Each object is used to instantiate a new instance of the relevant class (using Python’s handy some_function(**some_dict) trick). This object is added to the current session with session.add().
#
# Finally, when the session contains the rows to be added, session.commit() is used to commit the transaction to the database.

# %%
pd.read_sql("select * from uploads", con=engine)
# Out:
#     UploadId  UserId                                              Title  \
# 0          1       1  sunt aut facere repellat provident occaecati e...
# 1          2       1                                       qui est esse
# 2          3       1  ea molestias quasi exercitationem repellat qui...
# 3          4       1                               eum et est occaecati
# 4          5       1                                 nesciunt quas odio
# ..       ...     ...                                                ...
# 95        96      10  quaerat velit veniam amet cupiditate aut numqu...
# 96        97      10         quas fugiat ut perspiciatis vero provident
# 97        98      10                        laboriosam dolor voluptates
# 98        99      10  temporibus sit alias delectus eligendi possimu...
# 99       100      10              at nam consequatur ea labore ea harum
#
#                                                  Body  \
# 0   quia et suscipit\nsuscipit recusandae consequu...
# 1   est rerum tempore vitae\nsequi sint nihil repr...
# 2   et iusto sed quo iure\nvoluptatem occaecati om...
# 3   ullam et saepe reiciendis voluptatem adipisci\...
# 4   repudiandae veniam quaerat sunt sed\nalias aut...
# ..                                                ...
# 95  in non odio excepturi sint eum\nlabore volupta...
# 96  eum non blanditiis soluta porro quibusdam volu...
# 97  doloremque ex facilis sit sint culpa\nsoluta a...
# 98  quo deleniti praesentium dicta non quod\naut e...
# 99  cupiditate quo est a modi nesciunt soluta\nips...
#
#                      Timestamp
# 0   2021-06-07 23:08:03.031695
# 1   2021-06-07 21:02:10.031700
# 2   2021-06-08 05:04:49.031702
# 3   2021-06-08 16:20:04.031704
# 4   2021-06-07 20:42:02.031706
# ..                         ...
# 95  2021-06-08 00:01:38.031951
# 96  2021-06-07 21:25:40.031953
# 97  2021-06-08 02:38:59.031954
# 98  2021-06-08 06:44:09.031956
# 99  2021-06-08 01:21:51.031958
#
# [100 rows x 5 columns]

# %%
pd.read_sql("select * from users", con=engine)
# Out:
#    UserId Title FirstName  LastName                         Email  \
# 0       0    Mr    Curtis  Richards   curtis.richards@example.com
# 1       1    Mr     Chris  Ferguson    chris.ferguson@example.com
# 2       2    Mr   Anthony       Kim       anthony.kim@example.com
# 3       3    Ms  Nicoline    Larsen   nicoline.larsen@example.com
# 4       4    Mr     Lucas    Martin      lucas.martin@example.com
# 5       5    Mr     Craig   Coleman     craig.coleman@example.com
# 6       6    Mr  Muhammad   Lødemel  muhammad.lodemel@example.com
# 7       7  Miss     Ethel      Diaz        ethel.diaz@example.com
# 8       8    Ms    Eloane    Berger     eloane.berger@example.com
# 9       9    Mr    Justin       Roy        justin.roy@example.com
#
#              Username                         DOB
# 0     smallostrich277  1984-09-02 00:00:00.000000
# 1    silverostrich434  1992-08-20 00:00:00.000000
# 2     redbutterfly849  1957-08-28 00:00:00.000000
# 3         lazywolf848  1958-10-25 00:00:00.000000
# 4     angrymeercat769  1961-08-14 00:00:00.000000
# 5    purpleostrich376  1992-06-04 00:00:00.000000
# 6  ticklishmeercat301  1963-09-23 00:00:00.000000
# 7    ticklishpanda585  1995-05-29 00:00:00.000000
# 8     heavygorilla337  1975-12-16 00:00:00.000000
# 9     whitepeacock882  1981-07-25 00:00:00.000000

# %% [markdown]
# Notice that in the users.DOB column, the DOBs have redundant information (zeros) attached. This is expected by design. Since the DOB is in Datetime type (date + time), when inject with date type, the database will parse date type to datetime type and add time = 00:00:00.00000 by default.
#
# Lesson learnt: choose the proper data type when designing database. In this case, use date type for DOB.

# %%
# declare a new schema (class)
class UsersUploadsJoin(Base):
    __tablename__ = "users_uploads_join"
    __table_args__ = {'extend_existing': True} # add this line to make the schema modifiable
    UserId = Column(Integer, primary_key=True)
    UploadId = Column(Integer, primary_key=True)
    FirstName = Column(String)
    LastName = Column(String)
    Username = Column(String)
    DOB = Column(Date)
    UploadsTitle = Column(String)
    Body = Column(String)
    Timestamp = Column(DateTime)    
    
UsersUploadsJoin.__table__.create(bind=engine, checkfirst=True)

# %%
# verify
pd.read_sql("select * from sqlite_schema", con=engine).sql.apply(lambda x: print(x))
# Out:
# CREATE TABLE users (
# 	"UserId" INTEGER NOT NULL,
# 	"Title" VARCHAR,
# 	"FirstName" VARCHAR,
# 	"LastName" VARCHAR,
# 	"Email" VARCHAR,
# 	"Username" VARCHAR,
# 	"DOB" DATETIME,
# 	PRIMARY KEY ("UserId")
# )
# CREATE TABLE uploads (
# 	"UploadId" INTEGER NOT NULL,
# 	"UserId" INTEGER,
# 	"Title" VARCHAR,
# 	"Body" VARCHAR,
# 	"Timestamp" DATETIME,
# 	PRIMARY KEY ("UploadId"),
# 	FOREIGN KEY("UserId") REFERENCES users ("UserId")
# )
# CREATE TABLE users_uploads_join (
# 	"UserId" INTEGER NOT NULL,
# 	"UploadId" INTEGER NOT NULL,
# 	"FirstName" VARCHAR,
# 	"LastName" VARCHAR,
# 	"Username" VARCHAR,
# 	"DOB" DATE,
# 	"UploadsTitle" VARCHAR,
# 	"Body" VARCHAR,
# 	"Timestamp" DATETIME,
# 	PRIMARY KEY ("UserId", "UploadId")
# )
# None
# 0    None
# 1    None
# 2    None
# 3    None
# Name: sql, dtype: object

# %% [markdown]
# # All Together (with some modifications)
# Let's wrap it up to walk through the whole ETL process. We will extract users and uploads information from two APIs, join them gother and load it into the database with predefined schema.
# Stage1: E: extract from API
# Stage2: T: transform using Pandas
# Stage3:
# * step1: read the table schema from database (we are not going to create schema everytime, instead we will reflect schema and make sure the data to be injected match the schema)
# * step2: prepare the data to load. (We use Pandas in this step). A final check of data type and column name consistency.
# * step3: load data (in the context of SQL, INSERT INTO). Use a loading tool to abstract this process (we use sqlalchemy here)
#
# All the steps use methods we have seen before, at least in a high-level. We will make some modifications in some steps to make the workflow more concise and clearer.
#
# Since the first two stages (extract and transform) are very similar, our demo starts with stage 3.

# %%
# Stage3: loading
# step1: retrieve table schema (reflect)
from sqlalchemy.ext.automap import automap_base

Base_reflect = automap_base()
Base_reflect.prepare(engine, reflect=True)
print("table names: ", Base_reflect.classes.keys(), "\n")

# retrive schema stored in the sqlalchemy DeclarativeMeta class
JoinReflect = Base_reflect.classes.users_uploads_join
# print(type(JoinReflect), "\n")

# review the schema
for col in JoinReflect.__table__.columns:
    print(col.description, col.type)
[col for col in JoinReflect.__table__.columns]
# Out:
# table names:  ['uploads', 'users', 'users_uploads_join']
#
# UserId INTEGER
# UploadId INTEGER
# FirstName VARCHAR
# LastName VARCHAR
# Username VARCHAR
# DOB DATE
# UploadsTitle VARCHAR
# Body VARCHAR
# Timestamp DATETIME
# [Column('UserId', INTEGER(), table=<users_uploads_join>, primary_key=True, nullable=False),
#  Column('UploadId', INTEGER(), table=<users_uploads_join>, primary_key=True, nullable=False),
#  Column('FirstName', VARCHAR(), table=<users_uploads_join>),
#  Column('LastName', VARCHAR(), table=<users_uploads_join>),
#  Column('Username', VARCHAR(), table=<users_uploads_join>),
#  Column('DOB', DATE(), table=<users_uploads_join>),
#  Column('UploadsTitle', VARCHAR(), table=<users_uploads_join>),
#  Column('Body', VARCHAR(), table=<users_uploads_join>),
#  Column('Timestamp', DATETIME(), table=<users_uploads_join>)]

# %%
# step2: prep the TABLE users_uploads_join
# note: rename the column Title to UploadsTitle to match the schema
df_users = pd.DataFrame(users)
df_uploads = pd.DataFrame(uploads)
df_join = pd.merge(df_users[["UserId", "FirstName", "LastName", "Username", "DOB"]],
         df_uploads[["UserId", "UploadId", "Title", "Body", "Timestamp"]], on="UserId")\
        .rename(columns = {'Title': 'UploadsTitle'}, inplace = False)
df_join
# Out:
#     UserId FirstName  LastName          Username         DOB  UploadId  \
# 0        1     Chris  Ferguson  silverostrich434  1992-08-20         1
# 1        1     Chris  Ferguson  silverostrich434  1992-08-20         2
# 2        1     Chris  Ferguson  silverostrich434  1992-08-20         3
# 3        1     Chris  Ferguson  silverostrich434  1992-08-20         4
# 4        1     Chris  Ferguson  silverostrich434  1992-08-20         5
# ..     ...       ...       ...               ...         ...       ...
# 85       9    Justin       Roy   whitepeacock882  1981-07-25        86
# 86       9    Justin       Roy   whitepeacock882  1981-07-25        87
# 87       9    Justin       Roy   whitepeacock882  1981-07-25        88
# 88       9    Justin       Roy   whitepeacock882  1981-07-25        89
# 89       9    Justin       Roy   whitepeacock882  1981-07-25        90
#
#                                          UploadsTitle  \
# 0   sunt aut facere repellat provident occaecati e...
# 1                                        qui est esse
# 2   ea molestias quasi exercitationem repellat qui...
# 3                                eum et est occaecati
# 4                                  nesciunt quas odio
# ..                                                ...
# 85                         placeat quia et porro iste
# 86                         nostrum quis quasi placeat
# 87                           sapiente omnis fugit eos
# 88           sint soluta et vel magnam aut ut sed qui
# 89             ad iusto omnis odit dolor voluptatibus
#
#                                                  Body  \
# 0   quia et suscipit\nsuscipit recusandae consequu...
# 1   est rerum tempore vitae\nsequi sint nihil repr...
# 2   et iusto sed quo iure\nvoluptatem occaecati om...
# 3   ullam et saepe reiciendis voluptatem adipisci\...
# 4   repudiandae veniam quaerat sunt sed\nalias aut...
# ..                                                ...
# 85  quasi excepturi consequatur iste autem tempori...
# 86  eos et molestiae\nnesciunt ut a\ndolores persp...
# 87  consequatur omnis est praesentium\nducimus non...
# 88  repellat aut aperiam totam temporibus autem et...
# 89  minus omnis soluta quia\nqui sed adipisci volu...
#
#                     Timestamp
# 0  2021-06-07 23:08:03.031695
# 1  2021-06-07 21:02:10.031700
# 2  2021-06-08 05:04:49.031702
# 3  2021-06-08 16:20:04.031704
# 4  2021-06-07 20:42:02.031706
# ..                        ...
# 85 2021-06-08 04:32:34.031932
# 86 2021-06-08 04:25:41.031934
# 87 2021-06-08 01:08:18.031936
# 88 2021-06-07 20:41:08.031938
# 89 2021-06-08 11:16:08.031940
#
# [90 rows x 9 columns]

# %%
# modification 1: construct the join-lists
# A more concise join-list constructor using df.to_list("records")
list_join_dict = df_join.to_dict("records")
list_join_dict
# Out:
# [{'UserId': 1,
#   'FirstName': 'Chris',
#   'LastName': 'Ferguson',
#   'Username': 'silverostrich434',
#   'DOB': datetime.date(1992, 8, 20),
#   'UploadId': 1,
#   'UploadsTitle': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit',
#   'Body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto',
#   'Timestamp': Timestamp('2021-06-07 23:08:03.031695')},
#  {'UserId': 1,
#   'FirstName': 'Chris',
#   'LastName': 'Ferguson',
#   'Username': 'silverostrich434',
#   'DOB': datetime.date(1992, 8, 20),
#   'UploadId': 2,
#   'UploadsTitle': 'qui est esse',
#   'Body': 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla',
#   'Timestamp': Timestamp('2021-06-07 21:02:10.031700')},
#  {'UserId': 1,
#   'FirstName': 'Chris',
#   'LastName': 'Ferguson',
#   'Username': 'silverostrich434',
#   'DOB': datetime.date(1992, 8, 20),
#   'UploadId': 3,
#   'UploadsTitle': 'ea molestias quasi exercitationem repellat qui ipsa sit aut',
#   'Body': 'et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut',
#   'Timestamp': Timestamp('2021-06-08 05:04:49.031702')},
#  {'UserId': 1,
#   'FirstName': 'Chris',
#   'LastName': 'Ferguson',
#   'Username': 'silverostrich434',
#   'DOB': datetime.date(1992, 8, 20),
#   'UploadId': 4,
#   'UploadsTitle': 'eum et est occaecati',
#   'Body': 'ullam et saepe reiciendis voluptatem adipisci\nsit amet autem assumenda provident rerum culpa\nquis hic commodi nesciunt rem tenetur doloremque ipsam iure\nquis sunt voluptatem rerum illo velit',
#   'Timestamp': Timestamp('2021-06-08 16:20:04.031704')},
#  {'UserId': 1,
#   'FirstName': 'Chris',
#   'LastName': 'Ferguson',
#   'Username': 'silverostrich434',
#   'DOB': datetime.date(1992, 8, 20),
#   'UploadId': 5,
#   'UploadsTitle': 'nesciunt quas odio',
#   'Body': 'repudiandae veniam quaerat sunt sed\nalias aut fugiat sit autem sed est\nvoluptatem omnis possimus esse voluptatibus quis\nest aut tenetur dolor neque',
#   'Timestamp': Timestamp('2021-06-07 20:42:02.031706')},
#  {'UserId': 1,
#   'FirstName': 'Chris',
#   'LastName': 'Ferguson',
#   'Username': 'silverostrich434',
#   'DOB': datetime.date(1992, 8, 20),
#   'UploadId': 6,
#   'UploadsTitle': 'dolorem eum magni eos aperiam quia',
#   'Body': 'ut aspernatur corporis harum nihil quis provident sequi\nmollitia nobis aliquid molestiae\nperspiciatis et ea nemo ab reprehenderit accusantium quas\nvoluptate dolores velit et doloremque molestiae',
#   'Timestamp': Timestamp('2021-06-07 22:58:14.031708')},
#  {'UserId': 1,
#   'FirstName': 'Chris',
#   'LastName': 'Ferguson',
#   'Username': 'silverostrich434',
#   'DOB': datetime.date(1992, 8, 20),
#   'UploadId': 7,
#   'UploadsTitle': 'magnam facilis autem',
#   'Body': 'dolore placeat quibusdam ea quo vitae\nmagni quis enim qui quis quo nemo aut saepe\nquidem repellat excepturi ut quia\nsunt ut sequi eos ea sed quas',
#   'Timestamp': Timestamp('2021-06-07 23:23:02.031710')},
#  {'UserId': 1,
#   'FirstName': 'Chris',
#   'LastName': 'Ferguson',
#   'Username': 'silverostrich434',
#   'DOB': datetime.date(1992, 8, 20),
#   'UploadId': 8,
#   'UploadsTitle': 'dolorem dolore est ipsam',
#   'Body': 'dignissimos aperiam dolorem qui eum\nfacilis quibusdam animi sint suscipit qui sint possimus cum\nquaerat magni maiores excepturi\nipsam ut commodi dolor voluptatum modi aut vitae',
#   'Timestamp': Timestamp('2021-06-08 13:33:00.031712')},
#  {'UserId': 1,
#   'FirstName': 'Chris',
#   'LastName': 'Ferguson',
#   'Username': 'silverostrich434',
#   'DOB': datetime.date(1992, 8, 20),
#   'UploadId': 9,
#   'UploadsTitle': 'nesciunt iure omnis dolorem tempora et accusantium',
#   'Body': 'consectetur animi nesciunt iure dolore\nenim quia ad\nveniam autem ut quam aut nobis\net est aut quod aut provident voluptas autem voluptas',
#   'Timestamp': Timestamp('2021-06-08 10:07:33.031714')},
#  {'UserId': 1,
#   'FirstName': 'Chris',
#   'LastName': 'Ferguson',
#   'Username': 'silverostrich434',
#   'DOB': datetime.date(1992, 8, 20),
#   'UploadId': 10,
#   'UploadsTitle': 'optio molestias id quia eum',
#   'Body': 'quo et expedita modi cum officia vel magni\ndoloribus qui repudiandae\nvero nisi sit\nquos veniam quod sed accusamus veritatis error',
#   'Timestamp': Timestamp('2021-06-08 17:28:09.031717')},
#  {'UserId': 2,
#   'FirstName': 'Anthony',
#   'LastName': 'Kim',
#   'Username': 'redbutterfly849',
#   'DOB': datetime.date(1957, 8, 28),
#   'UploadId': 11,
#   'UploadsTitle': 'et ea vero quia laudantium autem',
#   'Body': 'delectus reiciendis molestiae occaecati non minima eveniet qui voluptatibus\naccusamus in eum beatae sit\nvel qui neque voluptates ut commodi qui incidunt\nut animi commodi',
#   'Timestamp': Timestamp('2021-06-07 19:17:44.031718')},
#  {'UserId': 2,
#   'FirstName': 'Anthony',
#   'LastName': 'Kim',
#   'Username': 'redbutterfly849',
#   'DOB': datetime.date(1957, 8, 28),
#   'UploadId': 12,
#   'UploadsTitle': 'in quibusdam tempore odit est dolorem',
#   'Body': 'itaque id aut magnam\npraesentium quia et ea odit et ea voluptas et\nsapiente quia nihil amet occaecati quia id voluptatem\nincidunt ea est distinctio odio',
#   'Timestamp': Timestamp('2021-06-08 10:13:45.031720')},
#  {'UserId': 2,
#   'FirstName': 'Anthony',
#   'LastName': 'Kim',
#   'Username': 'redbutterfly849',
#   'DOB': datetime.date(1957, 8, 28),
#   'UploadId': 13,
#   'UploadsTitle': 'dolorum ut in voluptas mollitia et saepe quo animi',
#   'Body': 'aut dicta possimus sint mollitia voluptas commodi quo doloremque\niste corrupti reiciendis voluptatem eius rerum\nsit cumque quod eligendi laborum minima\nperferendis recusandae assumenda consectetur porro architecto ipsum ipsam',
#   'Timestamp': Timestamp('2021-06-08 08:39:47.031723')},
#  {'UserId': 2,
#   'FirstName': 'Anthony',
#   'LastName': 'Kim',
#   'Username': 'redbutterfly849',
#   'DOB': datetime.date(1957, 8, 28),
#   'UploadId': 14,
#   'UploadsTitle': 'voluptatem eligendi optio',
#   'Body': 'fuga et accusamus dolorum perferendis illo voluptas\nnon doloremque neque facere\nad qui dolorum molestiae beatae\nsed aut voluptas totam sit illum',
#   'Timestamp': Timestamp('2021-06-08 17:02:12.031725')},
#  {'UserId': 2,
#   'FirstName': 'Anthony',
#   'LastName': 'Kim',
#   'Username': 'redbutterfly849',
#   'DOB': datetime.date(1957, 8, 28),
#   'UploadId': 15,
#   'UploadsTitle': 'eveniet quod temporibus',
#   'Body': 'reprehenderit quos placeat\nvelit minima officia dolores impedit repudiandae molestiae nam\nvoluptas recusandae quis delectus\nofficiis harum fugiat vitae',
#   'Timestamp': Timestamp('2021-06-07 19:28:09.031726')},
#  {'UserId': 2,
#   'FirstName': 'Anthony',
#   'LastName': 'Kim',
#   'Username': 'redbutterfly849',
#   'DOB': datetime.date(1957, 8, 28),
#   'UploadId': 16,
#   'UploadsTitle': 'sint suscipit perspiciatis velit dolorum rerum ipsa laboriosam odio',
#   'Body': 'suscipit nam nisi quo aperiam aut\nasperiores eos fugit maiores voluptatibus quia\nvoluptatem quis ullam qui in alias quia est\nconsequatur magni mollitia accusamus ea nisi voluptate dicta',
#   'Timestamp': Timestamp('2021-06-08 12:21:21.031729')},
#  {'UserId': 2,
#   'FirstName': 'Anthony',
#   'LastName': 'Kim',
#   'Username': 'redbutterfly849',
#   'DOB': datetime.date(1957, 8, 28),
#   'UploadId': 17,
#   'UploadsTitle': 'fugit voluptas sed molestias voluptatem provident',
#   'Body': 'eos voluptas et aut odit natus earum\naspernatur fuga molestiae ullam\ndeserunt ratione qui eos\nqui nihil ratione nemo velit ut aut id quo',
#   'Timestamp': Timestamp('2021-06-08 06:54:32.031730')},
#  {'UserId': 2,
#   'FirstName': 'Anthony',
#   'LastName': 'Kim',
#   'Username': 'redbutterfly849',
#   'DOB': datetime.date(1957, 8, 28),
#   'UploadId': 18,
#   'UploadsTitle': 'voluptate et itaque vero tempora molestiae',
#   'Body': 'eveniet quo quis\nlaborum totam consequatur non dolor\nut et est repudiandae\nest voluptatem vel debitis et magnam',
#   'Timestamp': Timestamp('2021-06-08 13:23:47.031732')},
#  {'UserId': 2,
#   'FirstName': 'Anthony',
#   'LastName': 'Kim',
#   'Username': 'redbutterfly849',
#   'DOB': datetime.date(1957, 8, 28),
#   'UploadId': 19,
#   'UploadsTitle': 'adipisci placeat illum aut reiciendis qui',
#   'Body': 'illum quis cupiditate provident sit magnam\nea sed aut omnis\nveniam maiores ullam consequatur atque\nadipisci quo iste expedita sit quos voluptas',
#   'Timestamp': Timestamp('2021-06-07 18:24:56.031734')},
#  {'UserId': 2,
#   'FirstName': 'Anthony',
#   'LastName': 'Kim',
#   'Username': 'redbutterfly849',
#   'DOB': datetime.date(1957, 8, 28),
#   'UploadId': 20,
#   'UploadsTitle': 'doloribus ad provident suscipit at',
#   'Body': 'qui consequuntur ducimus possimus quisquam amet similique\nsuscipit porro ipsam amet\neos veritatis officiis exercitationem vel fugit aut necessitatibus totam\nomnis rerum consequatur expedita quidem cumque explicabo',
#   'Timestamp': Timestamp('2021-06-08 03:36:28.031736')},
#  {'UserId': 3,
#   'FirstName': 'Nicoline',
#   'LastName': 'Larsen',
#   'Username': 'lazywolf848',
#   'DOB': datetime.date(1958, 10, 25),
#   'UploadId': 21,
#   'UploadsTitle': 'asperiores ea ipsam voluptatibus modi minima quia sint',
#   'Body': 'repellat aliquid praesentium dolorem quo\nsed totam minus non itaque\nnihil labore molestiae sunt dolor eveniet hic recusandae veniam\ntempora et tenetur expedita sunt',
#   'Timestamp': Timestamp('2021-06-08 09:42:01.031738')},
#  {'UserId': 3,
#   'FirstName': 'Nicoline',
#   'LastName': 'Larsen',
#   'Username': 'lazywolf848',
#   'DOB': datetime.date(1958, 10, 25),
#   'UploadId': 22,
#   'UploadsTitle': 'dolor sint quo a velit explicabo quia nam',
#   'Body': 'eos qui et ipsum ipsam suscipit aut\nsed omnis non odio\nexpedita earum mollitia molestiae aut atque rem suscipit\nnam impedit esse',
#   'Timestamp': Timestamp('2021-06-08 14:47:04.031740')},
#  {'UserId': 3,
#   'FirstName': 'Nicoline',
#   'LastName': 'Larsen',
#   'Username': 'lazywolf848',
#   'DOB': datetime.date(1958, 10, 25),
#   'UploadId': 23,
#   'UploadsTitle': 'maxime id vitae nihil numquam',
#   'Body': 'veritatis unde neque eligendi\nquae quod architecto quo neque vitae\nest illo sit tempora doloremque fugit quod\net et vel beatae sequi ullam sed tenetur perspiciatis',
#   'Timestamp': Timestamp('2021-06-08 02:12:01.031742')},
#  {'UserId': 3,
#   'FirstName': 'Nicoline',
#   'LastName': 'Larsen',
#   'Username': 'lazywolf848',
#   'DOB': datetime.date(1958, 10, 25),
#   'UploadId': 24,
#   'UploadsTitle': 'autem hic labore sunt dolores incidunt',
#   'Body': 'enim et ex nulla\nomnis voluptas quia qui\nvoluptatem consequatur numquam aliquam sunt\ntotam recusandae id dignissimos aut sed asperiores deserunt',
#   'Timestamp': Timestamp('2021-06-08 06:58:18.031744')},
#  {'UserId': 3,
#   'FirstName': 'Nicoline',
#   'LastName': 'Larsen',
#   'Username': 'lazywolf848',
#   'DOB': datetime.date(1958, 10, 25),
#   'UploadId': 25,
#   'UploadsTitle': 'rem alias distinctio quo quis',
#   'Body': 'ullam consequatur ut\nomnis quis sit vel consequuntur\nipsa eligendi ipsum molestiae et omnis error nostrum\nmolestiae illo tempore quia et distinctio',
#   'Timestamp': Timestamp('2021-06-08 16:00:16.031745')},
#  {'UserId': 3,
#   'FirstName': 'Nicoline',
#   'LastName': 'Larsen',
#   'Username': 'lazywolf848',
#   'DOB': datetime.date(1958, 10, 25),
#   'UploadId': 26,
#   'UploadsTitle': 'est et quae odit qui non',
#   'Body': 'similique esse doloribus nihil accusamus\nomnis dolorem fuga consequuntur reprehenderit fugit recusandae temporibus\nperspiciatis cum ut laudantium\nomnis aut molestiae vel vero',
#   'Timestamp': Timestamp('2021-06-08 09:02:30.031747')},
#  {'UserId': 3,
#   'FirstName': 'Nicoline',
#   'LastName': 'Larsen',
#   'Username': 'lazywolf848',
#   'DOB': datetime.date(1958, 10, 25),
#   'UploadId': 27,
#   'UploadsTitle': 'quasi id et eos tenetur aut quo autem',
#   'Body': 'eum sed dolores ipsam sint possimus debitis occaecati\ndebitis qui qui et\nut placeat enim earum aut odit facilis\nconsequatur suscipit necessitatibus rerum sed inventore temporibus consequatur',
#   'Timestamp': Timestamp('2021-06-08 15:32:24.031749')},
#  {'UserId': 3,
#   'FirstName': 'Nicoline',
#   'LastName': 'Larsen',
#   'Username': 'lazywolf848',
#   'DOB': datetime.date(1958, 10, 25),
#   'UploadId': 28,
#   'UploadsTitle': 'delectus ullam et corporis nulla voluptas sequi',
#   'Body': 'non et quaerat ex quae ad maiores\nmaiores recusandae totam aut blanditiis mollitia quas illo\nut voluptatibus voluptatem\nsimilique nostrum eum',
#   'Timestamp': Timestamp('2021-06-08 08:47:12.031751')},
#  {'UserId': 3,
#   'FirstName': 'Nicoline',
#   'LastName': 'Larsen',
#   'Username': 'lazywolf848',
#   'DOB': datetime.date(1958, 10, 25),
#   'UploadId': 29,
#   'UploadsTitle': 'iusto eius quod necessitatibus culpa ea',
#   'Body': 'odit magnam ut saepe sed non qui\ntempora atque nihil\naccusamus illum doloribus illo dolor\neligendi repudiandae odit magni similique sed cum maiores',
#   'Timestamp': Timestamp('2021-06-07 19:40:08.031753')},
#  {'UserId': 3,
#   'FirstName': 'Nicoline',
#   'LastName': 'Larsen',
#   'Username': 'lazywolf848',
#   'DOB': datetime.date(1958, 10, 25),
#   'UploadId': 30,
#   'UploadsTitle': 'a quo magni similique perferendis',
#   'Body': 'alias dolor cumque\nimpedit blanditiis non eveniet odio maxime\nblanditiis amet eius quis tempora quia autem rem\na provident perspiciatis quia',
#   'Timestamp': Timestamp('2021-06-08 10:04:48.031755')},
#  {'UserId': 4,
#   'FirstName': 'Lucas',
#   'LastName': 'Martin',
#   'Username': 'angrymeercat769',
#   'DOB': datetime.date(1961, 8, 14),
#   'UploadId': 31,
#   'UploadsTitle': 'ullam ut quidem id aut vel consequuntur',
#   'Body': 'debitis eius sed quibusdam non quis consectetur vitae\nimpedit ut qui consequatur sed aut in\nquidem sit nostrum et maiores adipisci atque\nquaerat voluptatem adipisci repudiandae',
#   'Timestamp': Timestamp('2021-06-08 07:43:24.031757')},
#  {'UserId': 4,
#   'FirstName': 'Lucas',
#   'LastName': 'Martin',
#   'Username': 'angrymeercat769',
#   'DOB': datetime.date(1961, 8, 14),
#   'UploadId': 32,
#   'UploadsTitle': 'doloremque illum aliquid sunt',
#   'Body': 'deserunt eos nobis asperiores et hic\nest debitis repellat molestiae optio\nnihil ratione ut eos beatae quibusdam distinctio maiores\nearum voluptates et aut adipisci ea maiores voluptas maxime',
#   'Timestamp': Timestamp('2021-06-08 02:25:21.031758')},
#  {'UserId': 4,
#   'FirstName': 'Lucas',
#   'LastName': 'Martin',
#   'Username': 'angrymeercat769',
#   'DOB': datetime.date(1961, 8, 14),
#   'UploadId': 33,
#   'UploadsTitle': 'qui explicabo molestiae dolorem',
#   'Body': 'rerum ut et numquam laborum odit est sit\nid qui sint in\nquasi tenetur tempore aperiam et quaerat qui in\nrerum officiis sequi cumque quod',
#   'Timestamp': Timestamp('2021-06-08 02:31:33.031760')},
#  {'UserId': 4,
#   'FirstName': 'Lucas',
#   'LastName': 'Martin',
#   'Username': 'angrymeercat769',
#   'DOB': datetime.date(1961, 8, 14),
#   'UploadId': 34,
#   'UploadsTitle': 'magnam ut rerum iure',
#   'Body': 'ea velit perferendis earum ut voluptatem voluptate itaque iusto\ntotam pariatur in\nnemo voluptatem voluptatem autem magni tempora minima in\nest distinctio qui assumenda accusamus dignissimos officia nesciunt nobis',
#   'Timestamp': Timestamp('2021-06-08 11:27:29.031833')},
#  {'UserId': 4,
#   'FirstName': 'Lucas',
#   'LastName': 'Martin',
#   'Username': 'angrymeercat769',
#   'DOB': datetime.date(1961, 8, 14),
#   'UploadId': 35,
#   'UploadsTitle': 'id nihil consequatur molestias animi provident',
#   'Body': 'nisi error delectus possimus ut eligendi vitae\nplaceat eos harum cupiditate facilis reprehenderit voluptatem beatae\nmodi ducimus quo illum voluptas eligendi\net nobis quia fugit',
#   'Timestamp': Timestamp('2021-06-08 14:36:31.031837')},
#  {'UserId': 4,
#   'FirstName': 'Lucas',
#   'LastName': 'Martin',
#   'Username': 'angrymeercat769',
#   'DOB': datetime.date(1961, 8, 14),
#   'UploadId': 36,
#   'UploadsTitle': 'fuga nam accusamus voluptas reiciendis itaque',
#   'Body': 'ad mollitia et omnis minus architecto odit\nvoluptas doloremque maxime aut non ipsa qui alias veniam\nblanditiis culpa aut quia nihil cumque facere et occaecati\nqui aspernatur quia eaque ut aperiam inventore',
#   'Timestamp': Timestamp('2021-06-08 09:46:21.031839')},
#  {'UserId': 4,
#   'FirstName': 'Lucas',
#   'LastName': 'Martin',
#   'Username': 'angrymeercat769',
#   'DOB': datetime.date(1961, 8, 14),
#   'UploadId': 37,
#   'UploadsTitle': 'provident vel ut sit ratione est',
#   'Body': 'debitis et eaque non officia sed nesciunt pariatur vel\nvoluptatem iste vero et ea\nnumquam aut expedita ipsum nulla in\nvoluptates omnis consequatur aut enim officiis in quam qui',
#   'Timestamp': Timestamp('2021-06-08 01:38:39.031842')},
#  {'UserId': 4,
#   'FirstName': 'Lucas',
#   'LastName': 'Martin',
#   'Username': 'angrymeercat769',
#   'DOB': datetime.date(1961, 8, 14),
#   'UploadId': 38,
#   'UploadsTitle': 'explicabo et eos deleniti nostrum ab id repellendus',
#   'Body': 'animi esse sit aut sit nesciunt assumenda eum voluptas\nquia voluptatibus provident quia necessitatibus ea\nrerum repudiandae quia voluptatem delectus fugit aut id quia\nratione optio eos iusto veniam iure',
#   'Timestamp': Timestamp('2021-06-07 22:26:20.031843')},
#  {'UserId': 4,
#   'FirstName': 'Lucas',
#   'LastName': 'Martin',
#   'Username': 'angrymeercat769',
#   'DOB': datetime.date(1961, 8, 14),
#   'UploadId': 39,
#   'UploadsTitle': 'eos dolorem iste accusantium est eaque quam',
#   'Body': 'corporis rerum ducimus vel eum accusantium\nmaxime aspernatur a porro possimus iste omnis\nest in deleniti asperiores fuga aut\nvoluptas sapiente vel dolore minus voluptatem incidunt ex',
#   'Timestamp': Timestamp('2021-06-08 02:08:04.031845')},
#  {'UserId': 4,
#   'FirstName': 'Lucas',
#   'LastName': 'Martin',
#   'Username': 'angrymeercat769',
#   'DOB': datetime.date(1961, 8, 14),
#   'UploadId': 40,
#   'UploadsTitle': 'enim quo cumque',
#   'Body': 'ut voluptatum aliquid illo tenetur nemo sequi quo facilis\nipsum rem optio mollitia quas\nvoluptatem eum voluptas qui\nunde omnis voluptatem iure quasi maxime voluptas nam',
#   'Timestamp': Timestamp('2021-06-08 10:37:25.031847')},
#  {'UserId': 5,
#   'FirstName': 'Craig',
#   'LastName': 'Coleman',
#   'Username': 'purpleostrich376',
#   'DOB': datetime.date(1992, 6, 4),
#   'UploadId': 41,
#   'UploadsTitle': 'non est facere',
#   'Body': 'molestias id nostrum\nexcepturi molestiae dolore omnis repellendus quaerat saepe\nconsectetur iste quaerat tenetur asperiores accusamus ex ut\nnam quidem est ducimus sunt debitis saepe',
#   'Timestamp': Timestamp('2021-06-08 08:40:02.031849')},
#  {'UserId': 5,
#   'FirstName': 'Craig',
#   'LastName': 'Coleman',
#   'Username': 'purpleostrich376',
#   'DOB': datetime.date(1992, 6, 4),
#   'UploadId': 42,
#   'UploadsTitle': 'commodi ullam sint et excepturi error explicabo praesentium voluptas',
#   'Body': 'odio fugit voluptatum ducimus earum autem est incidunt voluptatem\nodit reiciendis aliquam sunt sequi nulla dolorem\nnon facere repellendus voluptates quia\nratione harum vitae ut',
#   'Timestamp': Timestamp('2021-06-07 18:36:14.031851')},
#  {'UserId': 5,
#   'FirstName': 'Craig',
#   'LastName': 'Coleman',
#   'Username': 'purpleostrich376',
#   'DOB': datetime.date(1992, 6, 4),
#   'UploadId': 43,
#   'UploadsTitle': 'eligendi iste nostrum consequuntur adipisci praesentium sit beatae perferendis',
#   'Body': 'similique fugit est\nillum et dolorum harum et voluptate eaque quidem\nexercitationem quos nam commodi possimus cum odio nihil nulla\ndolorum exercitationem magnam ex et a et distinctio debitis',
#   'Timestamp': Timestamp('2021-06-08 07:21:40.031853')},
#  {'UserId': 5,
#   'FirstName': 'Craig',
#   'LastName': 'Coleman',
#   'Username': 'purpleostrich376',
#   'DOB': datetime.date(1992, 6, 4),
#   'UploadId': 44,
#   'UploadsTitle': 'optio dolor molestias sit',
#   'Body': 'temporibus est consectetur dolore\net libero debitis vel velit laboriosam quia\nipsum quibusdam qui itaque fuga rem aut\nea et iure quam sed maxime ut distinctio quae',
#   'Timestamp': Timestamp('2021-06-08 02:19:08.031854')},
#  {'UserId': 5,
#   'FirstName': 'Craig',
#   'LastName': 'Coleman',
#   'Username': 'purpleostrich376',
#   'DOB': datetime.date(1992, 6, 4),
#   'UploadId': 45,
#   'UploadsTitle': 'ut numquam possimus omnis eius suscipit laudantium iure',
#   'Body': 'est natus reiciendis nihil possimus aut provident\nex et dolor\nrepellat pariatur est\nnobis rerum repellendus dolorem autem',
#   'Timestamp': Timestamp('2021-06-08 00:49:50.031856')},
#  {'UserId': 5,
#   'FirstName': 'Craig',
#   'LastName': 'Coleman',
#   'Username': 'purpleostrich376',
#   'DOB': datetime.date(1992, 6, 4),
#   'UploadId': 46,
#   'UploadsTitle': 'aut quo modi neque nostrum ducimus',
#   'Body': 'voluptatem quisquam iste\nvoluptatibus natus officiis facilis dolorem\nquis quas ipsam\nvel et voluptatum in aliquid',
#   'Timestamp': Timestamp('2021-06-08 12:20:06.031858')},
#  {'UserId': 5,
#   'FirstName': 'Craig',
#   'LastName': 'Coleman',
#   'Username': 'purpleostrich376',
#   'DOB': datetime.date(1992, 6, 4),
#   'UploadId': 47,
#   'UploadsTitle': 'quibusdam cumque rem aut deserunt',
#   'Body': 'voluptatem assumenda ut qui ut cupiditate aut impedit veniam\noccaecati nemo illum voluptatem laudantium\nmolestiae beatae rerum ea iure soluta nostrum\neligendi et voluptate',
#   'Timestamp': Timestamp('2021-06-08 09:51:35.031860')},
#  {'UserId': 5,
#   'FirstName': 'Craig',
#   'LastName': 'Coleman',
#   'Username': 'purpleostrich376',
#   'DOB': datetime.date(1992, 6, 4),
#   'UploadId': 48,
#   'UploadsTitle': 'ut voluptatem illum ea doloribus itaque eos',
#   'Body': 'voluptates quo voluptatem facilis iure occaecati\nvel assumenda rerum officia et\nillum perspiciatis ab deleniti\nlaudantium repellat ad ut et autem reprehenderit',
#   'Timestamp': Timestamp('2021-06-08 12:08:26.031862')},
#  {'UserId': 5,
#   'FirstName': 'Craig',
#   'LastName': 'Coleman',
#   'Username': 'purpleostrich376',
#   'DOB': datetime.date(1992, 6, 4),
#   'UploadId': 49,
#   'UploadsTitle': 'laborum non sunt aut ut assumenda perspiciatis voluptas',
#   'Body': 'inventore ab sint\nnatus fugit id nulla sequi architecto nihil quaerat\neos tenetur in in eum veritatis non\nquibusdam officiis aspernatur cumque aut commodi aut',
#   'Timestamp': Timestamp('2021-06-08 16:42:21.031864')},
#  {'UserId': 5,
#   'FirstName': 'Craig',
#   'LastName': 'Coleman',
#   'Username': 'purpleostrich376',
#   'DOB': datetime.date(1992, 6, 4),
#   'UploadId': 50,
#   'UploadsTitle': 'repellendus qui recusandae incidunt voluptates tenetur qui omnis exercitationem',
#   'Body': 'error suscipit maxime adipisci consequuntur recusandae\nvoluptas eligendi et est et voluptates\nquia distinctio ab amet quaerat molestiae et vitae\nadipisci impedit sequi nesciunt quis consectetur',
#   'Timestamp': Timestamp('2021-06-08 02:28:13.031865')},
#  {'UserId': 6,
#   'FirstName': 'Muhammad',
#   'LastName': 'Lødemel',
#   'Username': 'ticklishmeercat301',
#   'DOB': datetime.date(1963, 9, 23),
#   'UploadId': 51,
#   'UploadsTitle': 'soluta aliquam aperiam consequatur illo quis voluptas',
#   'Body': 'sunt dolores aut doloribus\ndolore doloribus voluptates tempora et\ndoloremque et quo\ncum asperiores sit consectetur dolorem',
#   'Timestamp': Timestamp('2021-06-07 22:20:07.031867')},
#  {'UserId': 6,
#   'FirstName': 'Muhammad',
#   'LastName': 'Lødemel',
#   'Username': 'ticklishmeercat301',
#   'DOB': datetime.date(1963, 9, 23),
#   'UploadId': 52,
#   'UploadsTitle': 'qui enim et consequuntur quia animi quis voluptate quibusdam',
#   'Body': 'iusto est quibusdam fuga quas quaerat molestias\na enim ut sit accusamus enim\ntemporibus iusto accusantium provident architecto\nsoluta esse reprehenderit qui laborum',
#   'Timestamp': Timestamp('2021-06-08 03:30:24.031869')},
#  {'UserId': 6,
#   'FirstName': 'Muhammad',
#   'LastName': 'Lødemel',
#   'Username': 'ticklishmeercat301',
#   'DOB': datetime.date(1963, 9, 23),
#   'UploadId': 53,
#   'UploadsTitle': 'ut quo aut ducimus alias',
#   'Body': 'minima harum praesentium eum rerum illo dolore\nquasi exercitationem rerum nam\nporro quis neque quo\nconsequatur minus dolor quidem veritatis sunt non explicabo similique',
#   'Timestamp': Timestamp('2021-06-07 20:20:42.031871')},
#  {'UserId': 6,
#   'FirstName': 'Muhammad',
#   'LastName': 'Lødemel',
#   'Username': 'ticklishmeercat301',
#   'DOB': datetime.date(1963, 9, 23),
#   'UploadId': 54,
#   'UploadsTitle': 'sit asperiores ipsam eveniet odio non quia',
#   'Body': 'totam corporis dignissimos\nvitae dolorem ut occaecati accusamus\nex velit deserunt\net exercitationem vero incidunt corrupti mollitia',
#   'Timestamp': Timestamp('2021-06-08 01:03:37.031873')},
#  {'UserId': 6,
#   'FirstName': 'Muhammad',
#   'LastName': 'Lødemel',
#   'Username': 'ticklishmeercat301',
#   'DOB': datetime.date(1963, 9, 23),
#   'UploadId': 55,
#   'UploadsTitle': 'sit vel voluptatem et non libero',
#   'Body': 'debitis excepturi ea perferendis harum libero optio\neos accusamus cum fuga ut sapiente repudiandae\net ut incidunt omnis molestiae\nnihil ut eum odit',
#   'Timestamp': Timestamp('2021-06-07 22:17:11.031874')},
#  {'UserId': 6,
#   'FirstName': 'Muhammad',
#   'LastName': 'Lødemel',
#   'Username': 'ticklishmeercat301',
#   'DOB': datetime.date(1963, 9, 23),
#   'UploadId': 56,
#   'UploadsTitle': 'qui et at rerum necessitatibus',
#   'Body': 'aut est omnis dolores\nneque rerum quod ea rerum velit pariatur beatae excepturi\net provident voluptas corrupti\ncorporis harum reprehenderit dolores eligendi',
#   'Timestamp': Timestamp('2021-06-08 14:28:06.031876')},
#  {'UserId': 6,
#   'FirstName': 'Muhammad',
#   'LastName': 'Lødemel',
#   'Username': 'ticklishmeercat301',
#   'DOB': datetime.date(1963, 9, 23),
#   'UploadId': 57,
#   'UploadsTitle': 'sed ab est est',
#   'Body': 'at pariatur consequuntur earum quidem\nquo est laudantium soluta voluptatem\nqui ullam et est\net cum voluptas voluptatum repellat est',
#   'Timestamp': Timestamp('2021-06-08 14:52:34.031878')},
#  {'UserId': 6,
#   'FirstName': 'Muhammad',
#   'LastName': 'Lødemel',
#   'Username': 'ticklishmeercat301',
#   'DOB': datetime.date(1963, 9, 23),
#   'UploadId': 58,
#   'UploadsTitle': 'voluptatum itaque dolores nisi et quasi',
#   'Body': 'veniam voluptatum quae adipisci id\net id quia eos ad et dolorem\naliquam quo nisi sunt eos impedit error\nad similique veniam',
#   'Timestamp': Timestamp('2021-06-08 02:43:05.031880')},
#  {'UserId': 6,
#   'FirstName': 'Muhammad',
#   'LastName': 'Lødemel',
#   'Username': 'ticklishmeercat301',
#   'DOB': datetime.date(1963, 9, 23),
#   'UploadId': 59,
#   'UploadsTitle': 'qui commodi dolor at maiores et quis id accusantium',
#   'Body': 'perspiciatis et quam ea autem temporibus non voluptatibus qui\nbeatae a earum officia nesciunt dolores suscipit voluptas et\nanimi doloribus cum rerum quas et magni\net hic ut ut commodi expedita sunt',
#   'Timestamp': Timestamp('2021-06-08 05:27:19.031882')},
#  {'UserId': 6,
#   'FirstName': 'Muhammad',
#   'LastName': 'Lødemel',
#   'Username': 'ticklishmeercat301',
#   'DOB': datetime.date(1963, 9, 23),
#   'UploadId': 60,
#   'UploadsTitle': 'consequatur placeat omnis quisquam quia reprehenderit fugit veritatis facere',
#   'Body': 'asperiores sunt ab assumenda cumque modi velit\nqui esse omnis\nvoluptate et fuga perferendis voluptas\nillo ratione amet aut et omnis',
#   'Timestamp': Timestamp('2021-06-08 07:15:16.031884')},
#  {'UserId': 7,
#   'FirstName': 'Ethel',
#   'LastName': 'Diaz',
#   'Username': 'ticklishpanda585',
#   'DOB': datetime.date(1995, 5, 29),
#   'UploadId': 61,
#   'UploadsTitle': 'voluptatem doloribus consectetur est ut ducimus',
#   'Body': 'ab nemo optio odio\ndelectus tenetur corporis similique nobis repellendus rerum omnis facilis\nvero blanditiis debitis in nesciunt doloribus dicta dolores\nmagnam minus velit',
#   'Timestamp': Timestamp('2021-06-08 06:31:31.031886')},
#  {'UserId': 7,
#   'FirstName': 'Ethel',
#   'LastName': 'Diaz',
#   'Username': 'ticklishpanda585',
#   'DOB': datetime.date(1995, 5, 29),
#   'UploadId': 62,
#   'UploadsTitle': 'beatae enim quia vel',
#   'Body': 'enim aspernatur illo distinctio quae praesentium\nbeatae alias amet delectus qui voluptate distinctio\nodit sint accusantium autem omnis\nquo molestiae omnis ea eveniet optio',
#   'Timestamp': Timestamp('2021-06-07 17:55:10.031887')},
#  {'UserId': 7,
#   'FirstName': 'Ethel',
#   'LastName': 'Diaz',
#   'Username': 'ticklishpanda585',
#   'DOB': datetime.date(1995, 5, 29),
#   'UploadId': 63,
#   'UploadsTitle': 'voluptas blanditiis repellendus animi ducimus error sapiente et suscipit',
#   'Body': 'enim adipisci aspernatur nemo\nnumquam omnis facere dolorem dolor ex quis temporibus incidunt\nab delectus culpa quo reprehenderit blanditiis asperiores\naccusantium ut quam in voluptatibus voluptas ipsam dicta',
#   'Timestamp': Timestamp('2021-06-08 15:58:54.031889')},
#  {'UserId': 7,
#   'FirstName': 'Ethel',
#   'LastName': 'Diaz',
#   'Username': 'ticklishpanda585',
#   'DOB': datetime.date(1995, 5, 29),
#   'UploadId': 64,
#   'UploadsTitle': 'et fugit quas eum in in aperiam quod',
#   'Body': 'id velit blanditiis\neum ea voluptatem\nmolestiae sint occaecati est eos perspiciatis\nincidunt a error provident eaque aut aut qui',
#   'Timestamp': Timestamp('2021-06-07 20:39:00.031891')},
#  {'UserId': 7,
#   'FirstName': 'Ethel',
#   'LastName': 'Diaz',
#   'Username': 'ticklishpanda585',
#   'DOB': datetime.date(1995, 5, 29),
#   'UploadId': 65,
#   'UploadsTitle': 'consequatur id enim sunt et et',
#   'Body': 'voluptatibus ex esse\nsint explicabo est aliquid cumque adipisci fuga repellat labore\nmolestiae corrupti ex saepe at asperiores et perferendis\nnatus id esse incidunt pariatur',
#   'Timestamp': Timestamp('2021-06-07 23:08:57.031893')},
#  {'UserId': 7,
#   'FirstName': 'Ethel',
#   'LastName': 'Diaz',
#   'Username': 'ticklishpanda585',
#   'DOB': datetime.date(1995, 5, 29),
#   'UploadId': 66,
#   'UploadsTitle': 'repudiandae ea animi iusto',
#   'Body': 'officia veritatis tenetur vero qui itaque\nsint non ratione\nsed et ut asperiores iusto eos molestiae nostrum\nveritatis quibusdam et nemo iusto saepe',
#   'Timestamp': Timestamp('2021-06-08 02:51:28.031895')},
#  {'UserId': 7,
#   'FirstName': 'Ethel',
#   'LastName': 'Diaz',
#   'Username': 'ticklishpanda585',
#   'DOB': datetime.date(1995, 5, 29),
#   'UploadId': 67,
#   'UploadsTitle': 'aliquid eos sed fuga est maxime repellendus',
#   'Body': 'reprehenderit id nostrum\nvoluptas doloremque pariatur sint et accusantium quia quod aspernatur\net fugiat amet\nnon sapiente et consequatur necessitatibus molestiae',
#   'Timestamp': Timestamp('2021-06-08 08:45:29.031896')},
#  {'UserId': 7,
#   'FirstName': 'Ethel',
#   'LastName': 'Diaz',
#   'Username': 'ticklishpanda585',
#   'DOB': datetime.date(1995, 5, 29),
#   'UploadId': 68,
#   'UploadsTitle': 'odio quis facere architecto reiciendis optio',
#   'Body': 'magnam molestiae perferendis quisquam\nqui cum reiciendis\nquaerat animi amet hic inventore\nea quia deleniti quidem saepe porro velit',
#   'Timestamp': Timestamp('2021-06-08 15:18:29.031898')},
#  {'UserId': 7,
#   'FirstName': 'Ethel',
#   'LastName': 'Diaz',
#   'Username': 'ticklishpanda585',
#   'DOB': datetime.date(1995, 5, 29),
#   'UploadId': 69,
#   'UploadsTitle': 'fugiat quod pariatur odit minima',
#   'Body': 'officiis error culpa consequatur modi asperiores et\ndolorum assumenda voluptas et vel qui aut vel rerum\nvoluptatum quisquam perspiciatis quia rerum consequatur totam quas\nsequi commodi repudiandae asperiores et saepe a',
#   'Timestamp': Timestamp('2021-06-08 16:04:02.031900')},
#  {'UserId': 7,
#   'FirstName': 'Ethel',
#   'LastName': 'Diaz',
#   'Username': 'ticklishpanda585',
#   'DOB': datetime.date(1995, 5, 29),
#   'UploadId': 70,
#   'UploadsTitle': 'voluptatem laborum magni',
#   'Body': 'sunt repellendus quae\nest asperiores aut deleniti esse accusamus repellendus quia aut\nquia dolorem unde\neum tempora esse dolore',
#   'Timestamp': Timestamp('2021-06-08 11:25:04.031902')},
#  {'UserId': 8,
#   'FirstName': 'Eloane',
#   'LastName': 'Berger',
#   'Username': 'heavygorilla337',
#   'DOB': datetime.date(1975, 12, 16),
#   'UploadId': 71,
#   'UploadsTitle': 'et iusto veniam et illum aut fuga',
#   'Body': 'occaecati a doloribus\niste saepe consectetur placeat eum voluptate dolorem et\nqui quo quia voluptas\nrerum ut id enim velit est perferendis',
#   'Timestamp': Timestamp('2021-06-07 22:11:23.031903')},
#  {'UserId': 8,
#   'FirstName': 'Eloane',
#   'LastName': 'Berger',
#   'Username': 'heavygorilla337',
#   'DOB': datetime.date(1975, 12, 16),
#   'UploadId': 72,
#   'UploadsTitle': 'sint hic doloribus consequatur eos non id',
#   'Body': 'quam occaecati qui deleniti consectetur\nconsequatur aut facere quas exercitationem aliquam hic voluptas\nneque id sunt ut aut accusamus\nsunt consectetur expedita inventore velit',
#   'Timestamp': Timestamp('2021-06-07 19:52:09.031905')},
#  {'UserId': 8,
#   'FirstName': 'Eloane',
#   'LastName': 'Berger',
#   'Username': 'heavygorilla337',
#   'DOB': datetime.date(1975, 12, 16),
#   'UploadId': 73,
#   'UploadsTitle': 'consequuntur deleniti eos quia temporibus ab aliquid at',
#   'Body': 'voluptatem cumque tenetur consequatur expedita ipsum nemo quia explicabo\naut eum minima consequatur\ntempore cumque quae est et\net in consequuntur voluptatem voluptates aut',
#   'Timestamp': Timestamp('2021-06-08 09:30:20.031907')},
#  {'UserId': 8,
#   'FirstName': 'Eloane',
#   'LastName': 'Berger',
#   'Username': 'heavygorilla337',
#   'DOB': datetime.date(1975, 12, 16),
#   'UploadId': 74,
#   'UploadsTitle': 'enim unde ratione doloribus quas enim ut sit sapiente',
#   'Body': 'odit qui et et necessitatibus sint veniam\nmollitia amet doloremque molestiae commodi similique magnam et quam\nblanditiis est itaque\nquo et tenetur ratione occaecati molestiae tempora',
#   'Timestamp': Timestamp('2021-06-08 15:16:57.031910')},
#  {'UserId': 8,
#   'FirstName': 'Eloane',
#   'LastName': 'Berger',
#   'Username': 'heavygorilla337',
#   'DOB': datetime.date(1975, 12, 16),
#   'UploadId': 75,
#   'UploadsTitle': 'dignissimos eum dolor ut enim et delectus in',
#   'Body': 'commodi non non omnis et voluptas sit\nautem aut nobis magnam et sapiente voluptatem\net laborum repellat qui delectus facilis temporibus\nrerum amet et nemo voluptate expedita adipisci error dolorem',
#   'Timestamp': Timestamp('2021-06-08 15:57:13.031912')},
#  {'UserId': 8,
#   'FirstName': 'Eloane',
#   'LastName': 'Berger',
#   'Username': 'heavygorilla337',
#   'DOB': datetime.date(1975, 12, 16),
#   'UploadId': 76,
#   'UploadsTitle': 'doloremque officiis ad et non perferendis',
#   'Body': 'ut animi facere\ntotam iusto tempore\nmolestiae eum aut et dolorem aperiam\nquaerat recusandae totam odio',
#   'Timestamp': Timestamp('2021-06-08 15:12:10.031913')},
#  {'UserId': 8,
#   'FirstName': 'Eloane',
#   'LastName': 'Berger',
#   'Username': 'heavygorilla337',
#   'DOB': datetime.date(1975, 12, 16),
#   'UploadId': 77,
#   'UploadsTitle': 'necessitatibus quasi exercitationem odio',
#   'Body': 'modi ut in nulla repudiandae dolorum nostrum eos\naut consequatur omnis\nut incidunt est omnis iste et quam\nvoluptates sapiente aliquam asperiores nobis amet corrupti repudiandae provident',
#   'Timestamp': Timestamp('2021-06-07 23:45:42.031915')},
#  {'UserId': 8,
#   'FirstName': 'Eloane',
#   'LastName': 'Berger',
#   'Username': 'heavygorilla337',
#   'DOB': datetime.date(1975, 12, 16),
#   'UploadId': 78,
#   'UploadsTitle': 'quam voluptatibus rerum veritatis',
#   'Body': 'nobis facilis odit tempore cupiditate quia\nassumenda doloribus rerum qui ea\nillum et qui totam\naut veniam repellendus',
#   'Timestamp': Timestamp('2021-06-08 17:19:03.031917')},
#  {'UserId': 8,
#   'FirstName': 'Eloane',
#   'LastName': 'Berger',
#   'Username': 'heavygorilla337',
#   'DOB': datetime.date(1975, 12, 16),
#   'UploadId': 79,
#   'UploadsTitle': 'pariatur consequatur quia magnam autem omnis non amet',
#   'Body': 'libero accusantium et et facere incidunt sit dolorem\nnon excepturi qui quia sed laudantium\nquisquam molestiae ducimus est\nofficiis esse molestiae iste et quos',
#   'Timestamp': Timestamp('2021-06-08 13:15:40.031919')},
#  {'UserId': 8,
#   'FirstName': 'Eloane',
#   'LastName': 'Berger',
#   'Username': 'heavygorilla337',
#   'DOB': datetime.date(1975, 12, 16),
#   'UploadId': 80,
#   'UploadsTitle': 'labore in ex et explicabo corporis aut quas',
#   'Body': 'ex quod dolorem ea eum iure qui provident amet\nquia qui facere excepturi et repudiandae\nasperiores molestias provident\nminus incidunt vero fugit rerum sint sunt excepturi provident',
#   'Timestamp': Timestamp('2021-06-08 00:57:15.031921')},
#  {'UserId': 9,
#   'FirstName': 'Justin',
#   'LastName': 'Roy',
#   'Username': 'whitepeacock882',
#   'DOB': datetime.date(1981, 7, 25),
#   'UploadId': 81,
#   'UploadsTitle': 'tempora rem veritatis voluptas quo dolores vero',
#   'Body': 'facere qui nesciunt est voluptatum voluptatem nisi\nsequi eligendi necessitatibus ea at rerum itaque\nharum non ratione velit laboriosam quis consequuntur\nex officiis minima doloremque voluptas ut aut',
#   'Timestamp': Timestamp('2021-06-08 15:03:04.031923')},
#  {'UserId': 9,
#   'FirstName': 'Justin',
#   'LastName': 'Roy',
#   'Username': 'whitepeacock882',
#   'DOB': datetime.date(1981, 7, 25),
#   'UploadId': 82,
#   'UploadsTitle': 'laudantium voluptate suscipit sunt enim enim',
#   'Body': 'ut libero sit aut totam inventore sunt\nporro sint qui sunt molestiae\nconsequatur cupiditate qui iste ducimus adipisci\ndolor enim assumenda soluta laboriosam amet iste delectus hic',
#   'Timestamp': Timestamp('2021-06-08 07:27:16.031925')},
#  {'UserId': 9,
#   'FirstName': 'Justin',
#   'LastName': 'Roy',
#   'Username': 'whitepeacock882',
#   'DOB': datetime.date(1981, 7, 25),
#   'UploadId': 83,
#   'UploadsTitle': 'odit et voluptates doloribus alias odio et',
#   'Body': 'est molestiae facilis quis tempora numquam nihil qui\nvoluptate sapiente consequatur est qui\nnecessitatibus autem aut ipsa aperiam modi dolore numquam\nreprehenderit eius rem quibusdam',
#   'Timestamp': Timestamp('2021-06-08 00:14:47.031927')},
#  {'UserId': 9,
#   'FirstName': 'Justin',
#   'LastName': 'Roy',
#   'Username': 'whitepeacock882',
#   'DOB': datetime.date(1981, 7, 25),
#   'UploadId': 84,
#   'UploadsTitle': 'optio ipsam molestias necessitatibus occaecati facilis veritatis dolores aut',
#   'Body': 'sint molestiae magni a et quos\neaque et quasi\nut rerum debitis similique veniam\nrecusandae dignissimos dolor incidunt consequatur odio',
#   'Timestamp': Timestamp('2021-06-08 00:51:32.031929')},
#  {'UserId': 9,
#   'FirstName': 'Justin',
#   'LastName': 'Roy',
#   'Username': 'whitepeacock882',
#   'DOB': datetime.date(1981, 7, 25),
#   'UploadId': 85,
#   'UploadsTitle': 'dolore veritatis porro provident adipisci blanditiis et sunt',
#   'Body': 'similique sed nisi voluptas iusto omnis\nmollitia et quo\nassumenda suscipit officia magnam sint sed tempora\nenim provident pariatur praesentium atque animi amet ratione',
#   'Timestamp': Timestamp('2021-06-08 13:13:40.031930')},
#  {'UserId': 9,
#   'FirstName': 'Justin',
#   'LastName': 'Roy',
#   'Username': 'whitepeacock882',
#   'DOB': datetime.date(1981, 7, 25),
#   'UploadId': 86,
#   'UploadsTitle': 'placeat quia et porro iste',
#   'Body': 'quasi excepturi consequatur iste autem temporibus sed molestiae beatae\net quaerat et esse ut\nvoluptatem occaecati et vel explicabo autem\nasperiores pariatur deserunt optio',
#   'Timestamp': Timestamp('2021-06-08 04:32:34.031932')},
#  {'UserId': 9,
#   'FirstName': 'Justin',
#   'LastName': 'Roy',
#   'Username': 'whitepeacock882',
#   'DOB': datetime.date(1981, 7, 25),
#   'UploadId': 87,
#   'UploadsTitle': 'nostrum quis quasi placeat',
#   'Body': 'eos et molestiae\nnesciunt ut a\ndolores perspiciatis repellendus repellat aliquid\nmagnam sint rem ipsum est',
#   'Timestamp': Timestamp('2021-06-08 04:25:41.031934')},
#  {'UserId': 9,
#   'FirstName': 'Justin',
#   'LastName': 'Roy',
#   'Username': 'whitepeacock882',
#   'DOB': datetime.date(1981, 7, 25),
#   'UploadId': 88,
#   'UploadsTitle': 'sapiente omnis fugit eos',
#   'Body': 'consequatur omnis est praesentium\nducimus non iste\nneque hic deserunt\nvoluptatibus veniam cum et rerum sed',
#   'Timestamp': Timestamp('2021-06-08 01:08:18.031936')},
#  {'UserId': 9,
#   'FirstName': 'Justin',
#   'LastName': 'Roy',
#   'Username': 'whitepeacock882',
#   'DOB': datetime.date(1981, 7, 25),
#   'UploadId': 89,
#   'UploadsTitle': 'sint soluta et vel magnam aut ut sed qui',
#   'Body': 'repellat aut aperiam totam temporibus autem et\narchitecto magnam ut\nconsequatur qui cupiditate rerum quia soluta dignissimos nihil iure\ntempore quas est',
#   'Timestamp': Timestamp('2021-06-07 20:41:08.031938')},
#  {'UserId': 9,
#   'FirstName': 'Justin',
#   'LastName': 'Roy',
#   'Username': 'whitepeacock882',
#   'DOB': datetime.date(1981, 7, 25),
#   'UploadId': 90,
#   'UploadsTitle': 'ad iusto omnis odit dolor voluptatibus',
#   'Body': 'minus omnis soluta quia\nqui sed adipisci voluptates illum ipsam voluptatem\neligendi officia ut in\neos soluta similique molestias praesentium blanditiis',
#   'Timestamp': Timestamp('2021-06-08 11:16:08.031940')}]

# %%
# Note: "DOB" is actually in date() type even though it is displayed as "object" in df.info()
df_join.loc[[0]].DOB.apply(lambda x: print("DOB: ", type(x), "\n"))
df_join.info()
# Out:
# DOB:  <class 'datetime.date'>
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90 entries, 0 to 89
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   UserId        90 non-null     int64
#  1   FirstName     90 non-null     object
#  2   LastName      90 non-null     object
#  3   Username      90 non-null     object
#  4   DOB           90 non-null     object
#  5   UploadId      90 non-null     int64
#  6   UploadsTitle  90 non-null     object
#  7   Body          90 non-null     object
#  8   Timestamp     90 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(6)
# memory usage: 9.1+ KB

# %%
# modification2: using sqlalchemy bulk_insert_mappings
# Note: return_defaults=False, render_nulls=False by default. Better performance
# ref: bulk_insert_mappings: https://docs.sqlalchemy.org/en/14/orm/session_api.html#sqlalchemy.orm.Session.bulk_insert_mappings
# ref: Optimize Inserts Using SQLAlchemy: https://www.devx.com/dbzone/optimize-inserts-using-sqlalchemy.html
# ref: sqlalchemy session API: https://docs.sqlalchemy.org/en/14/orm/session_api.html#session-and-sessionmaker

with Session() as session:
    session.bulk_insert_mappings(JoinReflect, list_join_dict)
    session.commit()

# %%
# verify
pd.read_sql("select * from users_uploads_join", engine)
# Out:
#     UserId  UploadId FirstName  LastName          Username         DOB  \
# 0        1         1     Chris  Ferguson  silverostrich434  1992-08-20
# 1        1         2     Chris  Ferguson  silverostrich434  1992-08-20
# 2        1         3     Chris  Ferguson  silverostrich434  1992-08-20
# 3        1         4     Chris  Ferguson  silverostrich434  1992-08-20
# 4        1         5     Chris  Ferguson  silverostrich434  1992-08-20
# ..     ...       ...       ...       ...               ...         ...
# 85       9        86    Justin       Roy   whitepeacock882  1981-07-25
# 86       9        87    Justin       Roy   whitepeacock882  1981-07-25
# 87       9        88    Justin       Roy   whitepeacock882  1981-07-25
# 88       9        89    Justin       Roy   whitepeacock882  1981-07-25
# 89       9        90    Justin       Roy   whitepeacock882  1981-07-25
#
#                                          UploadsTitle  \
# 0   sunt aut facere repellat provident occaecati e...
# 1                                        qui est esse
# 2   ea molestias quasi exercitationem repellat qui...
# 3                                eum et est occaecati
# 4                                  nesciunt quas odio
# ..                                                ...
# 85                         placeat quia et porro iste
# 86                         nostrum quis quasi placeat
# 87                           sapiente omnis fugit eos
# 88           sint soluta et vel magnam aut ut sed qui
# 89             ad iusto omnis odit dolor voluptatibus
#
#                                                  Body  \
# 0   quia et suscipit\nsuscipit recusandae consequu...
# 1   est rerum tempore vitae\nsequi sint nihil repr...
# 2   et iusto sed quo iure\nvoluptatem occaecati om...
# 3   ullam et saepe reiciendis voluptatem adipisci\...
# 4   repudiandae veniam quaerat sunt sed\nalias aut...
# ..                                                ...
# 85  quasi excepturi consequatur iste autem tempori...
# 86  eos et molestiae\nnesciunt ut a\ndolores persp...
# 87  consequatur omnis est praesentium\nducimus non...
# 88  repellat aut aperiam totam temporibus autem et...
# 89  minus omnis soluta quia\nqui sed adipisci volu...
#
#                      Timestamp
# 0   2021-06-07 23:08:03.031695
# 1   2021-06-07 21:02:10.031700
# 2   2021-06-08 05:04:49.031702
# 3   2021-06-08 16:20:04.031704
# 4   2021-06-07 20:42:02.031706
# ..                         ...
# 85  2021-06-08 04:32:34.031932
# 86  2021-06-08 04:25:41.031934
# 87  2021-06-08 01:08:18.031936
# 88  2021-06-07 20:41:08.031938
# 89  2021-06-08 11:16:08.031940
#
# [90 rows x 9 columns]

# %%
# error handling: try to execute the following
# it should cause an error
with Session() as session:
    session.bulk_insert_mappings(JoinReflect, list_join_dict)
    session.commit()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# ~/anaconda3/envs/api/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1749                 if not evt_handled:
# -> 1750                     self.dialect.do_executemany(
#    1751                         cursor, statement, parameters, context
#
# ~/anaconda3/envs/api/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_executemany(self, cursor, statement, parameters, context)
#     713     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 714         cursor.executemany(statement, parameters)
#     715
#
# IntegrityError: UNIQUE constraint failed: users_uploads_join.UserId, users_uploads_join.UploadId
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-34-6ab9ebc2ee71> in <module>
#       1 # error handling: try to execute the following
#       2 with Session() as session:
# ----> 3     session.bulk_insert_mappings(JoinReflect, list_join_dict)
#       4     session.commit()
#
# ~/anaconda3/envs/api/lib/python3.8/site-packages/sqlalchemy/orm/session.py in bulk_insert_mappings(self, mapper, mappings, return_defaults, render_nulls)
#    3598
#    3599         """
# -> 3600         self._bulk_save_mappings(
#    3601             mapper,
#    3602             mappings,
#
# ~/anaconda3/envs/api/lib/python3.8/site-packages/sqlalchemy/orm/session.py in _bulk_save_mappings(self, mapper, mappings, isupdate, isstates, return_defaults, update_changed_only, render_nulls)
#    3697         except:
#    3698             with util.safe_reraise():
# -> 3699                 transaction.rollback(_capture_exception=True)
#    3700         finally:
#    3701             self._flushing = False
#
# ~/anaconda3/envs/api/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~/anaconda3/envs/api/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~/anaconda3/envs/api/lib/python3.8/site-packages/sqlalchemy/orm/session.py in _bulk_save_mappings(self, mapper, mappings, isupdate, isstates, return_defaults, update_changed_only, render_nulls)
#    3685                 )
#    3686             else:
# -> 3687                 persistence._bulk_insert(
#    3688                     mapper,
#    3689                     mappings,
#
# ~/anaconda3/envs/api/lib/python3.8/site-packages/sqlalchemy/orm/persistence.py in _bulk_insert(mapper, mappings, session_transaction, isstates, return_defaults, render_nulls)
#     102             )
#     103         )
# --> 104         _emit_insert_statements(
#     105             base_mapper,
#     106             None,
#
# ~/anaconda3/envs/api/lib/python3.8/site-packages/sqlalchemy/orm/persistence.py in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping)
#    1092             multiparams = [rec[2] for rec in records]
#    1093
# -> 1094             c = connection._execute_20(
#    1095                 statement, multiparams, execution_options=execution_options
#    1096             )
#
# ~/anaconda3/envs/api/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_20(self, statement, parameters, execution_options)
#    1580             )
#    1581         else:
# -> 1582             return meth(self, args_10style, kwargs_10style, execution_options)
#    1583
#    1584     def exec_driver_sql(
#
# ~/anaconda3/envs/api/lib/python3.8/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     327     ):
#     328         if _force or self.supports_execution:
# --> 329             return connection._execute_clauseelement(
#     330                 self, multiparams, params, execution_options
#     331             )
#
# ~/anaconda3/envs/api/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1449             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1450         )
# -> 1451         ret = self._execute_context(
#    1452             dialect,
#    1453             dialect.execution_ctx_cls._init_compiled,
#
# ~/anaconda3/envs/api/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1811
#    1812         except BaseException as e:
# -> 1813             self._handle_dbapi_exception(
#    1814                 e, statement, parameters, cursor, context
#    1815             )
#
# ~/anaconda3/envs/api/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1992                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1993             elif should_wrap:
# -> 1994                 util.raise_(
#    1995                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1996                 )
#
# ~/anaconda3/envs/api/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~/anaconda3/envs/api/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1748                             break
#    1749                 if not evt_handled:
# -> 1750                     self.dialect.do_executemany(
#    1751                         cursor, statement, parameters, context
#    1752                     )
#
# ~/anaconda3/envs/api/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_executemany(self, cursor, statement, parameters, context)
#     712
#     713     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 714         cursor.executemany(statement, parameters)
#     715
#     716     def do_execute(self, cursor, statement, parameters, context=None):
#
# IntegrityError: (sqlite3.IntegrityError) UNIQUE constraint failed: users_uploads_join.UserId, users_uploads_join.UploadId
# [SQL: INSERT INTO users_uploads_join ("UserId", "UploadId", "FirstName", "LastName", "Username", "DOB", "UploadsTitle", "Body", "Timestamp") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)]
# [parameters: ((1, 1, 'Chris', 'Ferguson', 'silverostrich434', '1992-08-20', 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto', '2021-06-07 23:08:03.031695'), (1, 2, 'Chris', 'Ferguson', 'silverostrich434', '1992-08-20', 'qui est esse', 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla', '2021-06-07 21:02:10.031700'), (1, 3, 'Chris', 'Ferguson', 'silverostrich434', '1992-08-20', 'ea molestias quasi exercitationem repellat qui ipsa sit aut', 'et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut', '2021-06-08 05:04:49.031702'), (1, 4, 'Chris', 'Ferguson', 'silverostrich434', '1992-08-20', 'eum et est occaecati', 'ullam et saepe reiciendis voluptatem adipisci\nsit amet autem assumenda provident rerum culpa\nquis hic commodi nesciunt rem tenetur doloremque ipsam iure\nquis sunt voluptatem rerum illo velit', '2021-06-08 16:20:04.031704'), (1, 5, 'Chris', 'Ferguson', 'silverostrich434', '1992-08-20', 'nesciunt quas odio', 'repudiandae veniam quaerat sunt sed\nalias aut fugiat sit autem sed est\nvoluptatem omnis possimus esse voluptatibus quis\nest aut tenetur dolor neque', '2021-06-07 20:42:02.031706'), (1, 6, 'Chris', 'Ferguson', 'silverostrich434', '1992-08-20', 'dolorem eum magni eos aperiam quia', 'ut aspernatur corporis harum nihil quis provident sequi\nmollitia nobis aliquid molestiae\nperspiciatis et ea nemo ab reprehenderit accusantium quas\nvoluptate dolores velit et doloremque molestiae', '2021-06-07 22:58:14.031708'), (1, 7, 'Chris', 'Ferguson', 'silverostrich434', '1992-08-20', 'magnam facilis autem', 'dolore placeat quibusdam ea quo vitae\nmagni quis enim qui quis quo nemo aut saepe\nquidem repellat excepturi ut quia\nsunt ut sequi eos ea sed quas', '2021-06-07 23:23:02.031710'), (1, 8, 'Chris', 'Ferguson', 'silverostrich434', '1992-08-20', 'dolorem dolore est ipsam', 'dignissimos aperiam dolorem qui eum\nfacilis quibusdam animi sint suscipit qui sint possimus cum\nquaerat magni maiores excepturi\nipsam ut commodi dolor voluptatum modi aut vitae', '2021-06-08 13:33:00.031712')  ... displaying 10 of 90 total bound parameter sets ...  (9, 89, 'Justin', 'Roy', 'whitepeacock882', '1981-07-25', 'sint soluta et vel magnam aut ut sed qui', 'repellat aut aperiam totam temporibus autem et\narchitecto magnam ut\nconsequatur qui cupiditate rerum quia soluta dignissimos nihil iure\ntempore quas est', '2021-06-07 20:41:08.031938'), (9, 90, 'Justin', 'Roy', 'whitepeacock882', '1981-07-25', 'ad iusto omnis odit dolor voluptatibus', 'minus omnis soluta quia\nqui sed adipisci voluptates illum ipsam voluptatem\neligendi officia ut in\neos soluta similique molestias praesentium blanditiis', '2021-06-08 11:16:08.031940'))]
# (Background on this error at: http://sqlalche.me/e/14/gkpj)

# %% [markdown]
# ## Warning
# * Pandas has its native method df.to_sql. In general this is not a good way to interact with RDBMS. Afterall, Pandas is at best used for processing and analysis. When it comes to database interaction, people have been claiming Pandas is very slow.
# * Another issue of Pandas is it might not be a good fit for big data. We will talk about how to handle big data in some other time.
# * You might notice that I have used pd.read_sql() in several situations. Be aware that the return query can be very large. So best practice, remember to add LIMIT in "SELECT * FROM ...LIMIT".

# %% [markdown]
# # Next
# ## Error handling, error handling, error handling
# ## Pipeline, orchestration
# ## Big data
