# %% [markdown]
# JSON is the format Square API return (along with many other APIs). Familiar with JSON and basic processing techniques is important. Consider the following:

# %%
# using SquareUp Client package
# note: how messy the result in string

from square.client import Client
sandbox_token = "EAAAEOoW41SpnUfDUo82nFAeC4NxtZOnn02jT66ChQTt6Dr_2iqBmz0u9hFt3ufx"

client = Client(
    access_token = sandbox_token,
    environment='sandbox',
)


result = client.payments.list_payments()

if result.is_success():
    print(result.body)
elif result.is_error():
    print(result.errors)
# Out:
# {'payments': [{'amount_money': {'amount': 15500, 'currency': 'USD'}, 'approved_money': {'amount': 15500, 'currency': 'USD'}, 'card_details': {'avs_status': 'AVS_ACCEPTED', 'card': {'bin': '540988', 'card_brand': 'MASTERCARD', 'card_type': 'CREDIT', 'exp_month': 5, 'exp_year': 2023, 'fingerprint': 'sq-1-7fcVk-Ggytsmj1IYgAMoKocTW6FzLYk8caCVduYXiBPyeuXdGSYctKvVU0DqO-zoAw', 'last_4': '9029', 'prepaid_type': 'NOT_PREPAID'}, 'card_payment_timeline': {'authorized_at': '2021-05-28T18:59:58.960Z', 'captured_at': '2021-05-28T18:59:59.146Z'}, 'cvv_status': 'CVV_ACCEPTED', 'entry_method': 'KEYED', 'statement_description': 'SQ *SQUARE SANDBOX NO2 G', 'status': 'CAPTURED'}, 'created_at': '2021-05-28T18:59:58.854Z', 'delay_action': 'CANCEL', 'delay_duration': 'PT168H', 'delayed_until': '2021-06-04T18:59:58.854Z', 'id': 'dIjp7s8hSKlhEtN80vQeL5hJCU9YY', 'location_id': 'LCN0KMDE4Y5WR', 'order_id': 'mZQcvAkRHb2bDQPHp1jmBY96cg4F', 'processing_fee': [{'amount_money': {'amount': 480, 'currency': 'USD'}, 'effective_at': '2021-05-28T20:59:59.000Z', 'type': 'INITIAL'}], 'receipt_number': 'dIjp', 'receipt_url': 'https://squareupsandbox.com/receipt/preview/dIjp7s8hSKlhEtN80vQeL5hJCU9YY', 'refund_ids': ['dIjp7s8hSKlhEtN80vQeL5hJCU9YY_TA24APiTljapc7SPhIdnfqf8XhB6dfXWGV7nSsNMwlb', 'dIjp7s8hSKlhEtN80vQeL5hJCU9YY_gL45RFnmwjhBM0hPTsVhYaj2DfMUBsAxHLew16y2ilO', 'dIjp7s8hSKlhEtN80vQeL5hJCU9YY_19sty2kiuUF9kNzhBRWOGgVwAbsSQ9yrlrnpaeQvf1W', 'dIjp7s8hSKlhEtN80vQeL5hJCU9YY_laMhNmju2hPt9kDSGzcRxKnCp4iTrZ3JQs9x7UqOvbV', 'dIjp7s8hSKlhEtN80vQeL5hJCU9YY_5oYhFfADB5sI8BAu5792hb4jfiaSdkFpIzyqnvGc9BT', 'dIjp7s8hSKlhEtN80vQeL5hJCU9YY_PvsutUPtwEVYGXWQVMhmGC2FvCLrGcfIaw7KQOnQqvF', 'dIjp7s8hSKlhEtN80vQeL5hJCU9YY_a6BLC27P4b0zo52HJd8AqbbuTAygOxacef5rXZJq6mJ'], 'refunded_money': {'amount': 40, 'currency': 'USD'}, 'risk_evaluation': {'created_at': '2021-05-28T18:59:58.960Z', 'risk_level': 'NORMAL'}, 'source_type': 'CARD', 'status': 'COMPLETED', 'total_money': {'amount': 15500, 'currency': 'USD'}, 'updated_at': '2021-05-28T20:38:29.019Z', 'version_token': 'dt9yEjn02DQ17BgniPUfdTgSCaXuwlDZQP1Or6OkLyn6o'}, {'amount_money': {'amount': 37500, 'currency': 'USD'}, 'approved_money': {'amount': 37500, 'currency': 'USD'}, 'card_details': {'avs_status': 'AVS_ACCEPTED', 'card': {'bin': '453275', 'card_brand': 'VISA', 'card_type': 'DEBIT', 'exp_month': 5, 'exp_year': 2023, 'fingerprint': 'sq-1-8GfB5DbWfI0TLLeFutEnasRHjltOm6-xCguYHuKmVaM0zfa7lqO7BQUotqmSZfbYUA', 'last_4': '5858', 'prepaid_type': 'NOT_PREPAID'}, 'card_payment_timeline': {'authorized_at': '2021-05-28T06:13:40.889Z', 'captured_at': '2021-05-28T06:13:40.969Z'}, 'cvv_status': 'CVV_ACCEPTED', 'entry_method': 'KEYED', 'statement_description': 'SQ *SQUARE SANDBOX NO2 G', 'status': 'CAPTURED'}, 'created_at': '2021-05-28T06:13:40.781Z', 'delay_action': 'CANCEL', 'delay_duration': 'PT168H', 'delayed_until': '2021-06-04T06:13:40.781Z', 'id': 'NeqnEc4nr6ohMhQeqc1pqVkJeWJZY', 'location_id': 'LCN0KMDE4Y5WR', 'note': '3 x Blu hat,6 x Small red shirt', 'order_id': 'y3SpWb4ZpKkUJ715nLFFr8HCOf4F', 'processing_fee': [{'amount_money': {'amount': 1118, 'currency': 'USD'}, 'effective_at': '2021-05-28T08:13:41.000Z', 'type': 'INITIAL'}], 'receipt_number': 'Neqn', 'receipt_url': 'https://squareupsandbox.com/receipt/preview/NeqnEc4nr6ohMhQeqc1pqVkJeWJZY', 'risk_evaluation': {'created_at': '2021-05-28T06:13:40.890Z', 'risk_level': 'NORMAL'}, 'source_type': 'CARD', 'status': 'COMPLETED', 'total_money': {'amount': 37500, 'currency': 'USD'}, 'updated_at': '2021-05-28T06:13:41.913Z', 'version_token': 'Bh0MNprqZ45ea8CrIJqUJY1A0Ujc23vFBDrkI3uU8i95o'}, {'amount_money': {'amount': 18000, 'currency': 'USD'}, 'approved_money': {'amount': 18000, 'currency': 'USD'}, 'card_details': {'avs_status': 'AVS_ACCEPTED', 'card': {'bin': '371263', 'card_brand': 'AMERICAN_EXPRESS', 'card_type': 'CREDIT', 'exp_month': 5, 'exp_year': 2023, 'fingerprint': 'sq-1-Lr1REofuIk_nZW5nWxnlCjAWvg2V9i3E4UI0jAUSQ7P-UVXKBWqGBZyv7CNMQF41XQ', 'last_4': '6550', 'prepaid_type': 'NOT_PREPAID'}, 'car ...

# %%
## part I: view JSON

### Option1: view inside notebook

# %%
## Add this to the first block in your note book to display json
# another option: 
import uuid
from IPython.core.display import display, HTML

import json

class RenderJSON(object):
    def __init__(self, json_data):
        if isinstance(json_data, dict):
            self.json_str = json.dumps(json_data)
        else:
            self.json_str = json_data
        self.uuid = str(uuid.uuid4())
        # This line is missed out in most of the versions of this script across the web, it is essential for this to work interleaved with print statements
#         self._ipython_display_()
        
    def _ipython_display_(self):
        display(HTML('<div id="{}" style="height: auto; width:100%;"></div>'.format(self.uuid)))
        display(HTML("""<script>
        require(["https://rawgit.com/caldwell/renderjson/master/renderjson.js"], function() {
          renderjson.set_show_to_level(1)
          document.getElementById('%s').appendChild(renderjson(%s))
        });</script>
        """ % (self.uuid, self.json_str)))

# %%
RenderJSON(result.body)
# Out:
# <div id="d192efc4-24fe-4caf-829b-a9471e209548" style="height: auto; width:100%;"></div>
# <script>
#         require(["https://rawgit.com/caldwell/renderjson/master/renderjson.js"], function() {
#           renderjson.set_show_to_level(1)
#           document.getElementById('d192efc4-24fe-4caf-829b-a9471e209548').appendChild(renderjson({"payments": [{"amount_money": {"amount": 15500, "currency": "USD"}, "approved_money": {"amount": 15500, "currency": "USD"}, "card_details": {"avs_status": "AVS_ACCEPTED", "card": {"bin": "540988", "card_brand": "MASTERCARD", "card_type": "CREDIT", "exp_month": 5, "exp_year": 2023, "fingerprint": "sq-1-7fcVk-Ggytsmj1IYgAMoKocTW6FzLYk8caCVduYXiBPyeuXdGSYctKvVU0DqO-zoAw", "last_4": "9029", "prepaid_type": "NOT_PREPAID"}, "card_payment_timeline": {"authorized_at": "2021-05-28T18:59:58.960Z", "captured_at": "2021-05-28T18:59:59.146Z"}, "cvv_status": "CVV_ACCEPTED", "entry_method": "KEYED", "statement_description": "SQ *SQUARE SANDBOX NO2 G", "status": "CAPTURED"}, "created_at": "2021-05-28T18:59:58.854Z", "delay_action": "CANCEL", "delay_duration": "PT168H", "delayed_until": "2021-06-04T18:59:58.854Z", "id": "dIjp7s8hSKlhEtN80vQeL5hJCU9YY", "location_id": "LCN0KMDE4Y5WR", "order_id": "mZQcvAkRHb2bDQPHp1jmBY96cg4F", "processing_fee": [{"amount_money": {"amount": 480, "currency": "USD"}, "effective_at": "2021-05-28T20:59:59.000Z", "type": "INITIAL"}], "receipt_number": "dIjp", "receipt_url": "https://squareupsandbox.com/receipt/preview/dIjp7s8hSKlhEtN80vQeL5hJCU9YY", "refund_ids": ["dIjp7s8hSKlhEtN80vQeL5hJCU9YY_TA24APiTljapc7SPhIdnfqf8XhB6dfXWGV7nSsNMwlb", "dIjp7s8hSKlhEtN80vQeL5hJCU9YY_gL45RFnmwjhBM0hPTsVhYaj2DfMUBsAxHLew16y2ilO", "dIjp7s8hSKlhEtN80vQeL5hJCU9YY_19sty2kiuUF9kNzhBRWOGgVwAbsSQ9yrlrnpaeQvf1W", "dIjp7s8hSKlhEtN80vQeL5hJCU9YY_laMhNmju2hPt9kDSGzcRxKnCp4iTrZ3JQs9x7UqOvbV", "dIjp7s8hSKlhEtN80vQeL5hJCU9YY_5oYhFfADB5sI8BAu5792hb4jfiaSdkFpIzyqnvGc9BT", "dIjp7s8hSKlhEtN80vQeL5hJCU9YY_PvsutUPtwEVYGXWQVMhmGC2FvCLrGcfIaw7KQOnQqvF", "dIjp7s8hSKlhEtN80vQeL5hJCU9YY_a6BLC27P4b0zo52HJd8AqbbuTAygOxacef5rXZJq6mJ"], "refunded_money": {"amount": 40, "currency": "USD"}, "risk_evaluation": {"created_at": "2021-05-28T18:59:58.960Z", "risk_level": "NORMAL"}, "source_type": "CARD", "status": "COMPLETED", "total_money": {"amount": 15500, "currency": "USD"}, "updated_at": "2021-05-28T20:38:29.019Z", "version_token": "dt9yEjn02DQ17BgniPUfdTgSCaXuwlDZQP1Or6OkLyn6o"}, {"amount_money": {"amount": 37500, "currency": "USD"}, "approved_money": {"amount": 37500, "currency": "USD"}, "card_details": {"avs_status": "AVS_ACCEPTED", "card": {"bin": "453275", "card_brand": "VISA", "card_type": "DEBIT", "exp_month": 5, "exp_year": 2023, "fingerprint": "sq-1-8GfB5DbWfI0TLLeFutEnasRHjltOm6-xCguYHuKmVaM0zfa7lqO7BQUotqmSZfbYUA", "last_4": "5858", "prepaid_type": "NOT_PREPAID"}, "card_payment_timeline": {"authorized_at": "2021-05-28T06:13:40.889Z", "captured_at": "2021-05-28T06:13:40.969Z"}, "cvv_status": "CVV_ACCEPTED", "entry_method": "KEYED", "statement_description": "SQ *SQUARE SANDBOX NO2 G", "status": "CAPTURED"}, "created_at": "2021-05-28T06:13:40.781Z", "delay_action": "CANCEL", "delay_duration": "PT168H", "delayed_until": "2021-06-04T06:13:40.781Z", "id": "NeqnEc4nr6ohMhQeqc1pqVkJeWJZY", "location_id": "LCN0KMDE4Y5WR", "note": "3 x Blu hat,6 x Small red shirt", "order_id": "y3SpWb4ZpKkUJ715nLFFr8HCOf4F", "processing_fee": [{"amount_money": {"amount": 1118, "currency": "USD"}, "effective_at": "2021-05-28T08:13:41.000Z", "type": "INITIAL"}], "receipt_number": "Neqn", "receipt_url": "https://squareupsandbox.com/receipt/preview/NeqnEc4nr6ohMhQeqc1pqVkJeWJZY", "risk_evaluation": {"created_at": "2021-05-28T06:13:40.890Z", "risk_level": "NORMAL"}, "source_type": "CARD", "status": "COMPLETED", "total_money": {"amount": 37500, "currency": "USD"}, "updated_at": "2021-05-28T06:13:41.913Z", "version_token": "Bh0MNprqZ45ea8CrIJqUJY1A0Ujc23vFBDrkI3uU8i95o"}, {"amount_money": {"amount": 18000, "currency": "USD"}, "approved_money": {"amount": 18000, "currency": "USD"}, "card_details": {"avs_status": "AVS_ACCEPTED", "card": {"bin": "371263", "card_brand": "AMERICAN_EXPRESS", "card_type": "CREDIT", "exp_month": 5, "exp_year": 2023, "fingerprint": "sq-1-Lr1REofuIk_nZW5nWxnlCjAWvg ...

# %%
# Part II: Parse JSON to Table

# %%
# note: adopt preferred packages and method if fit
# tips: JSON format is a bit similar to dictionary

# %%
# I will use pandas here
import pandas as pd
df = pd.DataFrame(result.body.get("payments"))
df.head()
# Out:
#                            amount_money                        approved_money  \
# 0  {'amount': 15500, 'currency': 'USD'}  {'amount': 15500, 'currency': 'USD'}
# 1  {'amount': 37500, 'currency': 'USD'}  {'amount': 37500, 'currency': 'USD'}
# 2  {'amount': 18000, 'currency': 'USD'}  {'amount': 18000, 'currency': 'USD'}
# 3  {'amount': 18000, 'currency': 'USD'}  {'amount': 18000, 'currency': 'USD'}
# 4  {'amount': 16500, 'currency': 'USD'}  {'amount': 16500, 'currency': 'USD'}
#
#                                         card_details  \
# 0  {'avs_status': 'AVS_ACCEPTED', 'card': {'bin':...
# 1  {'avs_status': 'AVS_ACCEPTED', 'card': {'bin':...
# 2  {'avs_status': 'AVS_ACCEPTED', 'card': {'bin':...
# 3  {'avs_status': 'AVS_ACCEPTED', 'card': {'bin':...
# 4  {'avs_status': 'AVS_ACCEPTED', 'card': {'bin':...
#
#                  created_at delay_action delay_duration  \
# 0  2021-05-28T18:59:58.854Z       CANCEL         PT168H
# 1  2021-05-28T06:13:40.781Z       CANCEL         PT168H
# 2  2021-05-28T06:03:54.314Z       CANCEL         PT168H
# 3  2021-05-28T05:53:11.544Z       CANCEL         PT168H
# 4  2021-05-27T23:41:48.029Z       CANCEL         PT168H
#
#               delayed_until                             id    location_id  \
# 0  2021-06-04T18:59:58.854Z  dIjp7s8hSKlhEtN80vQeL5hJCU9YY  LCN0KMDE4Y5WR
# 1  2021-06-04T06:13:40.781Z  NeqnEc4nr6ohMhQeqc1pqVkJeWJZY  LCN0KMDE4Y5WR
# 2  2021-06-04T06:03:54.314Z  bTxT6yfAqCkl63NKCzIyweXQGJZZY  LCN0KMDE4Y5WR
# 3  2021-06-04T05:53:11.544Z  HLW3H2q1I5glQXgchhXDhAc1A95YY  LCN0KMDE4Y5WR
# 4  2021-06-03T23:41:48.029Z  7Z2gqg12ldVdymOHio9uwRKVFxNZY  LCN0KMDE4Y5WR
#
#                        order_id  ...  \
# 0  mZQcvAkRHb2bDQPHp1jmBY96cg4F  ...
# 1  y3SpWb4ZpKkUJ715nLFFr8HCOf4F  ...
# 2  W7ZWfMcNy03CiPbdn2PxYP3Ysg4F  ...
# 3  W5SDFdTFSEPQuPATz4mLwkHEta4F  ...
# 4  wYxuBFr3Z2sq65QpNuzWBImRZc4F  ...
#
#                                          receipt_url  \
# 0  https://squareupsandbox.com/receipt/preview/dI...
# 1  https://squareupsandbox.com/receipt/preview/Ne...
# 2  https://squareupsandbox.com/receipt/preview/bT...
# 3  https://squareupsandbox.com/receipt/preview/HL...
# 4  https://squareupsandbox.com/receipt/preview/7Z...
#
#                                           refund_ids  \
# 0  [dIjp7s8hSKlhEtN80vQeL5hJCU9YY_TA24APiTljapc7S...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  [7Z2gqg12ldVdymOHio9uwRKVFxNZY_hiuXsma0FNoYKZM...
#
#                         refunded_money  \
# 0    {'amount': 40, 'currency': 'USD'}
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4  {'amount': 6000, 'currency': 'USD'}
#
#                                      risk_evaluation source_type     status  \
# 0  {'created_at': '2021-05-28T18:59:58.960Z', 'ri...        CARD  COMPLETED
# 1  {'created_at': '2021-05-28T06:13:40.890Z', 'ri...        CARD  COMPLETED
# 2  {'created_at': '2021-05-28T06:03:54.421Z', 'ri...        CARD  COMPLETED
# 3  {'created_at': '2021-05-28T05:53:11.650Z', 'ri...        CARD  COMPLETED
# 4  {'created_at': '2021-05-27T23:41:48.136Z', 'ri...        CARD  COMPLETED
#
#                             total_money                updated_at  \
# 0  {'amount': 15500, 'currency': 'USD'}  2021-05-28T20:38:29.019Z
# 1  {'amount': 37500, 'currency': 'USD'}  2021-05-28T06:13:41.913Z
# 2  {'amount': 18000, 'currency': 'USD'}  2021-05-28T06:03:55.584Z
# 3  {'amount': 18000, 'currency': 'USD'}  2021-05-28T05:53:12.640Z
# 4  {'amount': 16500, 'currency': 'USD'}  2021-05-28T04:46:23.775Z
#
#                                    version_token  \
# 0  dt9yEjn02DQ17BgniPUfdTgSCaXuwlDZQP1Or6OkLyn6o
# 1  Bh0MNprqZ45ea8CrIJqUJY1A0Ujc23vFBDrkI3uU8i95o
# 2  jh8Ou1WI0OnOtzrw8gQvtvyGJ6OubJWS8UEflcrs6LF6o
# 3  SGNR227ebGH3bZx7qABCOVKArc1gmmzusvuiHPalW7T6o
# 4  wFzUFsjHBDxDmywlRlGuC0yWY5fldJEdUNWOshrsOo65o
#
#                               note
# 0                              NaN
# 1  3 x Blu hat,6 x Small red shirt
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   amount_money     8 non-null      object
#  1   approved_money   8 non-null      object
#  2   card_details     8 non-null      object
#  3   created_at       8 non-null      object
#  4   delay_action     8 non-null      object
#  5   delay_duration   8 non-null      object
#  6   delayed_until    8 non-null      object
#  7   id               8 non-null      object
#  8   location_id      8 non-null      object
#  9   order_id         8 non-null      object
#  10  processing_fee   7 non-null      object
#  11  receipt_number   7 non-null      object
#  12  receipt_url      7 non-null      object
#  13  refund_ids       2 non-null      object
#  14  refunded_money   2 non-null      object
#  15  risk_evaluation  8 non-null      object
#  16  source_type      8 non-null      object
#  17  status           8 non-null      object
#  18  total_money      8 non-null      object
#  19  updated_at       8 non-null      object
#  20  version_token    8 non-null      object
#  21  note             1 non-null      object
# dtypes: object(22)
# memory usage: 1.5+ KB

# %%
# certain columns can be further flattened as follows
# note: amount_money is flattened to payments.amount and payments.currency
df_flat = pd.json_normalize(result.body.get("payments"))
df_flat.head()
# Out:
#                  created_at delay_action delay_duration  \
# 0  2021-05-28T18:59:58.854Z       CANCEL         PT168H
# 1  2021-05-28T06:13:40.781Z       CANCEL         PT168H
# 2  2021-05-28T06:03:54.314Z       CANCEL         PT168H
# 3  2021-05-28T05:53:11.544Z       CANCEL         PT168H
# 4  2021-05-27T23:41:48.029Z       CANCEL         PT168H
#
#               delayed_until                             id    location_id  \
# 0  2021-06-04T18:59:58.854Z  dIjp7s8hSKlhEtN80vQeL5hJCU9YY  LCN0KMDE4Y5WR
# 1  2021-06-04T06:13:40.781Z  NeqnEc4nr6ohMhQeqc1pqVkJeWJZY  LCN0KMDE4Y5WR
# 2  2021-06-04T06:03:54.314Z  bTxT6yfAqCkl63NKCzIyweXQGJZZY  LCN0KMDE4Y5WR
# 3  2021-06-04T05:53:11.544Z  HLW3H2q1I5glQXgchhXDhAc1A95YY  LCN0KMDE4Y5WR
# 4  2021-06-03T23:41:48.029Z  7Z2gqg12ldVdymOHio9uwRKVFxNZY  LCN0KMDE4Y5WR
#
#                        order_id  \
# 0  mZQcvAkRHb2bDQPHp1jmBY96cg4F
# 1  y3SpWb4ZpKkUJ715nLFFr8HCOf4F
# 2  W7ZWfMcNy03CiPbdn2PxYP3Ysg4F
# 3  W5SDFdTFSEPQuPATz4mLwkHEta4F
# 4  wYxuBFr3Z2sq65QpNuzWBImRZc4F
#
#                                       processing_fee receipt_number  \
# 0  [{'amount_money': {'amount': 480, 'currency': ...           dIjp
# 1  [{'amount_money': {'amount': 1118, 'currency':...           Neqn
# 2  [{'amount_money': {'amount': 552, 'currency': ...           bTxT
# 3  [{'amount_money': {'amount': 552, 'currency': ...           HLW3
# 4  [{'amount_money': {'amount': 509, 'currency': ...           7Z2g
#
#                                          receipt_url  ...  \
# 0  https://squareupsandbox.com/receipt/preview/dI...  ...
# 1  https://squareupsandbox.com/receipt/preview/Ne...  ...
# 2  https://squareupsandbox.com/receipt/preview/bT...  ...
# 3  https://squareupsandbox.com/receipt/preview/HL...  ...
# 4  https://squareupsandbox.com/receipt/preview/7Z...  ...
#
#   card_details.statement_description card_details.status  \
# 0           SQ *SQUARE SANDBOX NO2 G            CAPTURED
# 1           SQ *SQUARE SANDBOX NO2 G            CAPTURED
# 2           SQ *SQUARE SANDBOX NO2 G            CAPTURED
# 3           SQ *SQUARE SANDBOX NO2 G            CAPTURED
# 4           SQ *SQUARE SANDBOX NO2 G            CAPTURED
#
#   refunded_money.amount refunded_money.currency risk_evaluation.created_at  \
# 0                  40.0                     USD   2021-05-28T18:59:58.960Z
# 1                   NaN                     NaN   2021-05-28T06:13:40.890Z
# 2                   NaN                     NaN   2021-05-28T06:03:54.421Z
# 3                   NaN                     NaN   2021-05-28T05:53:11.650Z
# 4                6000.0                     USD   2021-05-27T23:41:48.136Z
#
#    risk_evaluation.risk_level total_money.amount  total_money.currency  \
# 0                      NORMAL              15500                   USD
# 1                      NORMAL              37500                   USD
# 2                      NORMAL              18000                   USD
# 3                      NORMAL              18000                   USD
# 4                      NORMAL              16500                   USD
#
#                               note  \
# 0                              NaN
# 1  3 x Blu hat,6 x Small red shirt
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
#   card_details.card_payment_timeline.voided_at
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
# [5 rows x 42 columns]

# %%
df_flat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 42 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   created_at                                        8 non-null      object
#  1   delay_action                                      8 non-null      object
#  2   delay_duration                                    8 non-null      object
#  3   delayed_until                                     8 non-null      object
#  4   id                                                8 non-null      object
#  5   location_id                                       8 non-null      object
#  6   order_id                                          8 non-null      object
#  7   processing_fee                                    7 non-null      object
#  8   receipt_number                                    7 non-null      object
#  9   receipt_url                                       7 non-null      object
#  10  refund_ids                                        2 non-null      object
#  11  source_type                                       8 non-null      object
#  12  status                                            8 non-null      object
#  13  updated_at                                        8 non-null      object
#  14  version_token                                     8 non-null      object
#  15  amount_money.amount                               8 non-null      int64
#  16  amount_money.currency                             8 non-null      object
#  17  approved_money.amount                             8 non-null      int64
#  18  approved_money.currency                           8 non-null      object
#  19  card_details.avs_status                           8 non-null      object
#  20  card_details.card.bin                             8 non-null      object
#  21  card_details.card.card_brand                      8 non-null      object
#  22  card_details.card.card_type                       8 non-null      object
#  23  card_details.card.exp_month                       8 non-null      int64
#  24  card_details.card.exp_year                        8 non-null      int64
#  25  card_details.card.fingerprint                     8 non-null      object
#  26  card_details.card.last_4                          8 non-null      object
#  27  card_details.card.prepaid_type                    8 non-null      object
#  28  card_details.card_payment_timeline.authorized_at  8 non-null      object
#  29  card_details.card_payment_timeline.captured_at    7 non-null      object
#  30  card_details.cvv_status                           8 non-null      object
#  31  card_details.entry_method                         8 non-null      object
#  32  card_details.statement_description                8 non-null      object
#  33  card_details.status                               8 non-null      object
#  34  refunded_money.amount                             2 non-null      float64
#  35  refunded_money.currency                           2 non-null      object
#  36  risk_evaluation.created_at                        8 non-null      object
#  37  risk_evaluation.risk_level                        8 non-null      object
#  38  total_money.amount                                8 non-null      int64
#  39  total_money.currency                              8 non-null      object
#  40  note                                              1 non-null      object
#  41  card_details.card_payment_timeline.voided_at      1 non-null      object
# dtypes: float64(1), int64(5), object(36)
# memory usage: 2.8+ KB
