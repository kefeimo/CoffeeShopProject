# %%
import json
import pandas as pd
from bs4 import BeautifulSoup as bs

# %%
respond_string = """{
  "payments": [
    {
      "id": "1YH4A3G2vyv2ejVP419qN4LJ0jPZY",
      "created_at": "2021-05-06T17:18:36.496Z",
      "updated_at": "2021-05-06T17:18:37.487Z",
      "amount_money": {
        "amount": 436,
        "currency": "USD"
      },
      "status": "COMPLETED",
      "delay_duration": "PT168H",
      "source_type": "CARD",
      "card_details": {
        "status": "CAPTURED",
        "card": {
          "card_brand": "AMERICAN_EXPRESS",
          "last_4": "6550",
          "exp_month": 1,
          "exp_year": 2023,
          "fingerprint": "sq-1-AH9rkQMBA0QufaD-5lfVTMy7w0dnzOTAltrkHjVe_z5G-XPJtx4xT3S6RDXadWUGIQ",
          "card_type": "CREDIT",
          "prepaid_type": "NOT_PREPAID",
          "bin": "371263"
        },
        "entry_method": "ON_FILE",
        "cvv_status": "CVV_NOT_CHECKED",
        "avs_status": "AVS_ACCEPTED",
        "statement_description": "SQ *DEFAULT TEST ACCOUNT",
        "card_payment_timeline": {
          "authorized_at": "2021-05-06T17:18:36.603Z",
          "captured_at": "2021-05-06T17:18:36.657Z"
        }
      },
      "location_id": "LS2TXDC8CSGZN",
      "order_id": "BH7O6aT82bAeUQE2jaoTvI5AJf4F",
      "risk_evaluation": {
        "created_at": "2021-05-06T17:18:36.603Z",
        "risk_level": "NORMAL"
      },
      "processing_fee": [
        {
          "effective_at": "2021-05-06T19:18:37.000Z",
          "type": "INITIAL",
          "amount_money": {
            "amount": 43,
            "currency": "USD"
          }
        }
      ],
      "note": "cappuccino",
      "total_money": {
        "amount": 436,
        "currency": "USD"
      },
      "approved_money": {
        "amount": 436,
        "currency": "USD"
      },
      "receipt_number": "1YH4",
      "receipt_url": "https://squareupsandbox.com/receipt/preview/1YH4A3G2vyv2ejVP419qN4LJ0jPZY",
      "delay_action": "CANCEL",
      "delayed_until": "2021-05-13T17:18:36.496Z",
      "version_token": "xKnohxIxzOSHFIvYjmD638Zyfq2hSylw2MDIbXu0mMD6o"
    },
    {
      "id": "ZcOXsHdFQYe6mscHrfI1n9XVTp5YY",
      "created_at": "2021-05-06T17:17:28.993Z",
      "updated_at": "2021-05-06T17:17:29.621Z",
      "amount_money": {
        "amount": 3608,
        "currency": "USD"
      },
      "status": "COMPLETED",
      "delay_duration": "PT168H",
      "source_type": "CARD",
      "card_details": {
        "status": "CAPTURED",
        "card": {
          "card_brand": "AMERICAN_EXPRESS",
          "last_4": "6550",
          "exp_month": 1,
          "exp_year": 2023,
          "fingerprint": "sq-1-AH9rkQMBA0QufaD-5lfVTMy7w0dnzOTAltrkHjVe_z5G-XPJtx4xT3S6RDXadWUGIQ",
          "card_type": "CREDIT",
          "prepaid_type": "NOT_PREPAID",
          "bin": "371263"
        },
        "entry_method": "ON_FILE",
        "cvv_status": "CVV_NOT_CHECKED",
        "avs_status": "AVS_ACCEPTED",
        "statement_description": "SQ *DEFAULT TEST ACCOUNT",
        "card_payment_timeline": {
          "authorized_at": "2021-05-06T17:17:29.102Z",
          "captured_at": "2021-05-06T17:17:29.157Z"
        }
      },
      "location_id": "LS2TXDC8CSGZN",
      "order_id": "B3xLPvknK07igJsWtnXkVgYuag4F",
      "risk_evaluation": {
        "created_at": "2021-05-06T17:17:29.102Z",
        "risk_level": "NORMAL"
      },
      "processing_fee": [
        {
          "effective_at": "2021-05-06T19:17:29.000Z",
          "type": "INITIAL",
          "amount_money": {
            "amount": 135,
            "currency": "USD"
          }
        }
      ],
      "note": "chai",
      "total_money": {
        "amount": 3608,
        "currency": "USD"
      },
      "approved_money": {
        "amount": 3608,
        "currency": "USD"
      },
      "receipt_number": "ZcOX",
      "receipt_url": "https://squareupsandbox.com/receipt/preview/ZcOXsHdFQYe6mscHrfI1n9XVTp5YY",
      "delay_action": "CANCEL",
      "delayed_until": "2021-05-13T17:17:28.993Z",
      "version_token": "uVySwVGSGxsSvKHh8nysl7dcVwUR3zeX5wcu7NipuTT6o"
    },
    {
      "id": "tcbG7J79thsEQuYsts0npMcl3MGZY",
      "created_at": "2021-05-06T17:15:47.423Z",
      "updated_at": "2021-05-06T17:15:49.002Z",
      "amount_money": {
        "amount": 2000,
        "currency": "USD"
      },
      "status": "COMPLETED",
      "delay_duration": "PT168H",
      "source_type": "CARD",
      "card_details": {
        "status": "CAPTURED",
        "card": {
          "card_brand": "AMERICAN_EXPRESS",
          "last_4": "6550",
          "exp_month": 1,
          "exp_year": 2023,
          "fingerprint": "sq-1-AH9rkQMBA0QufaD-5lfVTMy7w0dnzOTAltrkHjVe_z5G-XPJtx4xT3S6RDXadWUGIQ",
          "card_type": "CREDIT",
          "prepaid_type": "NOT_PREPAID",
          "bin": "371263"
        },
        "entry_method": "ON_FILE",
        "cvv_status": "CVV_NOT_CHECKED",
        "avs_status": "AVS_ACCEPTED",
        "statement_description": "SQ *DEFAULT TEST ACCOUNT",
        "card_payment_timeline": {
          "authorized_at": "2021-05-06T17:15:47.531Z",
          "captured_at": "2021-05-06T17:15:47.595Z"
        }
      },
      "location_id": "LS2TXDC8CSGZN",
      "order_id": "Bhcu5ofCoDxPz8OewOIjWSeYnd4F",
      "risk_evaluation": {
        "created_at": "2021-05-06T17:15:47.531Z",
        "risk_level": "NORMAL"
      },
      "processing_fee": [
        {
          "effective_at": "2021-05-06T19:15:49.000Z",
          "type": "INITIAL",
          "amount_money": {
            "amount": 88,
            "currency": "USD"
          }
        }
      ],
      "note": "latte",
      "total_money": {
        "amount": 2000,
        "currency": "USD"
      },
      "approved_money": {
        "amount": 2000,
        "currency": "USD"
      },
      "receipt_number": "tcbG",
      "receipt_url": "https://squareupsandbox.com/receipt/preview/tcbG7J79thsEQuYsts0npMcl3MGZY",
      "delay_action": "CANCEL",
      "delayed_until": "2021-05-13T17:15:47.423Z",
      "version_token": "W51AbuMFrsm4IrPPZrpF59sUa3R3wgpEsoxGCgRXi975o"
    },
    {
      "id": "zDxcvcbsI4jHuGpiIOehkwWGfbMZY",
      "created_at": "2021-04-22T02:51:31.858Z",
      "updated_at": "2021-04-22T02:51:33.210Z",
      "amount_money": {
        "amount": 1000,
        "currency": "USD"
      },
      "status": "COMPLETED",
      "delay_duration": "PT168H",
      "source_type": "CARD",
      "card_details": {
        "status": "CAPTURED",
        "card": {
          "card_brand": "MASTERCARD",
          "last_4": "9029",
          "exp_month": 4,
          "exp_year": 2023,
          "fingerprint": "sq-1-7XP2GN5R87-KKsp-pH1irRVqU90Mb2sWCCtbfTTbuIKX9e2CczP2HIYPoyP9C2xGXw",
          "card_type": "CREDIT",
          "prepaid_type": "NOT_PREPAID",
          "bin": "540988"
        },
        "entry_method": "KEYED",
        "cvv_status": "CVV_ACCEPTED",
        "avs_status": "AVS_ACCEPTED",
        "statement_description": "SQ *DEFAULT TEST ACCOUNT",
        "card_payment_timeline": {
          "authorized_at": "2021-04-22T02:51:31.978Z",
          "captured_at": "2021-04-22T02:51:32.071Z"
        }
      },
      "location_id": "LS2TXDC8CSGZN",
      "order_id": "RZy93T3Txak4cLEbAHqKSdQ1yb4F",
      "risk_evaluation": {
        "created_at": "2021-04-22T02:51:31.979Z",
        "risk_level": "NORMAL"
      },
      "processing_fee": [
        {
          "effective_at": "2021-04-22T04:51:33.000Z",
          "type": "INITIAL",
          "amount_money": {
            "amount": 59,
            "currency": "USD"
          }
        }
      ],
      "note": "some drink",
      "total_money": {
        "amount": 1000,
        "currency": "USD"
      },
      "approved_money": {
        "amount": 1000,
        "currency": "USD"
      },
      "receipt_number": "zDxc",
      "receipt_url": "https://squareupsandbox.com/receipt/preview/zDxcvcbsI4jHuGpiIOehkwWGfbMZY",
      "delay_action": "CANCEL",
      "delayed_until": "2021-04-29T02:51:31.858Z",
      "version_token": "h3Xxv6mvKQemppBENBV8df3Hzlsybgj5AwN4xdtcqgC6o"
    },
    {
      "id": "pw0BxLrUQ9ydCyqaP4OJLFSuucTZY",
      "created_at": "2021-04-21T23:53:21.668Z",
      "updated_at": "2021-04-21T23:53:22.726Z",
      "amount_money": {
        "amount": 356,
        "currency": "USD"
      },
      "status": "COMPLETED",
      "delay_duration": "PT168H",
      "source_type": "CARD",
      "card_details": {
        "status": "CAPTURED",
        "card": {
          "card_brand": "AMERICAN_EXPRESS",
          "last_4": "6550",
          "exp_month": 1,
          "exp_year": 2023,
          "fingerprint": "sq-1-AH9rkQMBA0QufaD-5lfVTMy7w0dnzOTAltrkHjVe_z5G-XPJtx4xT3S6RDXadWUGIQ",
          "card_type": "CREDIT",
          "prepaid_type": "NOT_PREPAID",
          "bin": "371263"
        },
        "entry_method": "ON_FILE",
        "cvv_status": "CVV_NOT_CHECKED",
        "avs_status": "AVS_ACCEPTED",
        "statement_description": "SQ *DEFAULT TEST ACCOUNT",
        "card_payment_timeline": {
          "authorized_at": "2021-04-21T23:53:21.784Z",
          "captured_at": "2021-04-21T23:53:21.843Z"
        }
      },
      "location_id": "LS2TXDC8CSGZN",
      "order_id": "JpA7f8FJ8KMKT6oAGs5KiqfJra4F",
      "risk_evaluation": {
        "created_at": "2021-04-21T23:53:21.784Z",
        "risk_level": "NORMAL"
      },
      "processing_fee": [
        {
          "effective_at": "2021-04-22T01:53:22.000Z",
          "type": "INITIAL",
          "amount_money": {
            "amount": 40,
            "currency": "USD"
          }
        }
      ],
      "note": "Toasted Coconut Latte (16oz ICED) - beachy, summery, poolside vibes with our caramelized coconut flavor. // 16oz HOT lattes come with four shots by default",
      "total_money": {
        "amount": 356,
        "currency": "USD"
      },
      "approved_money": {
        "amount": 356,
        "currency": "USD"
      },
      "receipt_number": "pw0B",
      "receipt_url": "https://squareupsandbox.com/receipt/preview/pw0BxLrUQ9ydCyqaP4OJLFSuucTZY",
      "delay_action": "CANCEL",
      "delayed_until": "2021-04-28T23:53:21.668Z",
      "version_token": "pK8Lt5KT1iTtJI0HaHyA1x73ijkOUY06L3wJJtQGxXi6o"
    },
    {
      "id": "Ng9SVs6bKIwNOTr5i0PxBlF3xCQZY",
      "created_at": "2021-04-21T23:41:47.862Z",
      "updated_at": "2021-04-21T23:41:49.342Z",
      "amount_money": {
        "amount": 100000,
        "currency": "USD"
      },
      "status": "COMPLETED",
      "delay_duration": "PT168H",
      "source_type": "CARD",
      "card_details": {
        "status": "CAPTURED",
        "card": {
          "card_brand": "AMERICAN_EXPRESS",
          "last_4": "6550",
          "exp_month": 4,
          "exp_year": 2023,
          "fingerprint": "sq-1-AH9rkQMBA0QufaD-5lfVTMy7w0dnzOTAltrkHjVe_z5G-XPJtx4xT3S6RDXadWUGIQ",
          "card_type": "CREDIT",
          "prepaid_type": "NOT_PREPAID",
          "bin": "371263"
        },
        "entry_method": "KEYED",
        "cvv_status": "CVV_ACCEPTED",
        "avs_status": "AVS_ACCEPTED",
        "statement_description": "SQ *DEFAULT TEST ACCOUNT",
        "card_payment_timeline": {
          "authorized_at": "2021-04-21T23:41:48.032Z",
          "captured_at": "2021-04-21T23:41:48.119Z"
        }
      },
      "location_id": "LS2TXDC8CSGZN",
      "order_id": "tn8wiXmHw1joc92tmzT2glHB7Z4F",
      "risk_evaluation": {
        "created_at": "2021-04-21T23:41:48.032Z",
        "risk_level": "NORMAL"
      },
      "processing_fee": [
        {
          "effective_at": "2021-04-22T01:41:49.000Z",
          "type": "INITIAL",
          "amount_money": {
            "amount": 2930,
            "currency": "USD"
          }
        }
      ],
      "total_money": {
        "amount": 100000,
        "currency": "USD"
      },
      "approved_money": {
        "amount": 100000,
        "currency": "USD"
      },
      "receipt_number": "Ng9S",
      "receipt_url": "https://squareupsandbox.com/receipt/preview/Ng9SVs6bKIwNOTr5i0PxBlF3xCQZY",
      "delay_action": "CANCEL",
      "delayed_until": "2021-04-28T23:41:47.862Z",
      "version_token": "brGzKMJC3q2SxfeOeUoQcWlCdxPJEF1ck5bE5LgvcIv6o"
    },
    {
      "id": "FWYdT4ICNQLjbjYN3CIFoQinCh8YY",
      "created_at": "2021-04-15T02:24:40.532Z",
      "updated_at": "2021-04-15T02:24:41.268Z",
      "amount_money": {
        "amount": 1000,
        "currency": "USD"
      },
      "status": "COMPLETED",
      "delay_duration": "PT168H",
      "source_type": "CARD",
      "card_details": {
        "status": "CAPTURED",
        "card": {
          "card_brand": "MASTERCARD",
          "last_4": "9029",
          "exp_month": 4,
          "exp_year": 2023,
          "fingerprint": "sq-1-7XP2GN5R87-KKsp-pH1irRVqU90Mb2sWCCtbfTTbuIKX9e2CczP2HIYPoyP9C2xGXw",
          "card_type": "CREDIT",
          "prepaid_type": "NOT_PREPAID",
          "bin": "540988"
        },
        "entry_method": "KEYED",
        "cvv_status": "CVV_ACCEPTED",
        "avs_status": "AVS_ACCEPTED",
        "statement_description": "SQ *DEFAULT TEST ACCOUNT",
        "card_payment_timeline": {
          "authorized_at": "2021-04-15T02:24:40.648Z",
          "captured_at": "2021-04-15T02:24:40.754Z"
        }
      },
      "location_id": "LS2TXDC8CSGZN",
      "order_id": "VbyRjuilgJo7iuX929SFGYTDHa4F",
      "risk_evaluation": {
        "created_at": "2021-04-15T02:24:40.648Z",
        "risk_level": "NORMAL"
      },
      "processing_fee": [
        {
          "effective_at": "2021-04-15T04:24:41.000Z",
          "type": "INITIAL",
          "amount_money": {
            "amount": 59,
            "currency": "USD"
          }
        }
      ],
      "total_money": {
        "amount": 1000,
        "currency": "USD"
      },
      "approved_money": {
        "amount": 1000,
        "currency": "USD"
      },
      "receipt_number": "FWYd",
      "receipt_url": "https://squareupsandbox.com/receipt/preview/FWYdT4ICNQLjbjYN3CIFoQinCh8YY",
      "delay_action": "CANCEL",
      "delayed_until": "2021-04-22T02:24:40.532Z",
      "version_token": "oyyenjbxUxmuQOlxgI64YnMl2JNxhMC2HZs2lPnyRxu6o"
    },
    {
      "id": "rRM7KKQc99UAduir98Uq91719SdZY",
      "created_at": "2021-04-14T20:29:41.591Z",
      "updated_at": "2021-04-14T20:29:42.493Z",
      "amount_money": {
        "amount": 100,
        "currency": "USD"
      },
      "status": "COMPLETED",
      "delay_duration": "PT168H",
      "source_type": "CARD",
      "card_details": {
        "status": "CAPTURED",
        "card": {
          "card_brand": "VISA",
          "last_4": "5858",
          "exp_month": 4,
          "exp_year": 2023,
          "fingerprint": "sq-1-fTOnkJlCWUDk8h2haVmxCvTGSUXUQBBaioU14U__LnB9CPOIOLqSD22dlXxOB-fbAg",
          "card_type": "DEBIT",
          "prepaid_type": "NOT_PREPAID",
          "bin": "453275"
        },
        "entry_method": "KEYED",
        "cvv_status": "CVV_ACCEPTED",
        "avs_status": "AVS_ACCEPTED",
        "statement_description": "SQ *DEFAULT TEST ACCOUNT",
        "card_payment_timeline": {
          "authorized_at": "2021-04-14T20:29:41.701Z",
          "captured_at": "2021-04-14T20:29:41.783Z"
        }
      },
      "location_id": "LS2TXDC8CSGZN",
      "order_id": "pvrHDzqkwamIbGnFnGez3EpSPf4F",
      "risk_evaluation": {
        "created_at": "2021-04-14T20:29:41.701Z",
        "risk_level": "NORMAL"
      },
      "processing_fee": [
        {
          "effective_at": "2021-04-14T22:29:42.000Z",
          "type": "INITIAL",
          "amount_money": {
            "amount": 33,
            "currency": "USD"
          }
        }
      ],
      "total_money": {
        "amount": 100,
        "currency": "USD"
      },
      "approved_money": {
        "amount": 100,
        "currency": "USD"
      },
      "receipt_number": "rRM7",
      "receipt_url": "https://squareupsandbox.com/receipt/preview/rRM7KKQc99UAduir98Uq91719SdZY",
      "delay_action": "CANCEL",
      "delayed_until": "2021-04-21T20:29:41.591Z",
      "version_token": "ahBcuwyz75vuaPyjfkRqi8B1YxHPAO83KQLJ9hQGfcr6o"
    }
  ]
}"""

# %%
respond_json = json.loads(respond_string)

# %%
# print(respond_json["payments"])

# %%
print(json.dumps(respond_json,indent=2))
# Out:
# {
#   "payments": [
#     {
#       "id": "1YH4A3G2vyv2ejVP419qN4LJ0jPZY",
#       "created_at": "2021-05-06T17:18:36.496Z",
#       "updated_at": "2021-05-06T17:18:37.487Z",
#       "amount_money": {
#         "amount": 436,
#         "currency": "USD"
#       },
#       "status": "COMPLETED",
#       "delay_duration": "PT168H",
#       "source_type": "CARD",
#       "card_details": {
#         "status": "CAPTURED",
#         "card": {
#           "card_brand": "AMERICAN_EXPRESS",
#           "last_4": "6550",
#           "exp_month": 1,
#           "exp_year": 2023,
#           "fingerprint": "sq-1-AH9rkQMBA0QufaD-5lfVTMy7w0dnzOTAltrkHjVe_z5G-XPJtx4xT3S6RDXadWUGIQ",
#           "card_type": "CREDIT",
#           "prepaid_type": "NOT_PREPAID",
#           "bin": "371263"
#         },
#         "entry_method": "ON_FILE",
#         "cvv_status": "CVV_NOT_CHECKED",
#         "avs_status": "AVS_ACCEPTED",
#         "statement_description": "SQ *DEFAULT TEST ACCOUNT",
# ...

# %%
# Pandas read from json file
# with open('respond.json', 'w') as outfile:
#     json.dump(respond_json, outfile)
# res_df = pd.read_json("respond.json")

# %%
# Pandas read from object-like json
# use eval method
res_df = pd.DataFrame(eval(respond_string))

# %%
res_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   payments  8 non-null      object
# dtypes: object(1)
# memory usage: 192.0+ bytes

# %%
# original json -> Pandas df (single column)
res_df
# Out:
#                                             payments
# 0  {'id': '1YH4A3G2vyv2ejVP419qN4LJ0jPZY', 'creat...
# 1  {'id': 'ZcOXsHdFQYe6mscHrfI1n9XVTp5YY', 'creat...
# 2  {'id': 'tcbG7J79thsEQuYsts0npMcl3MGZY', 'creat...
# 3  {'id': 'zDxcvcbsI4jHuGpiIOehkwWGfbMZY', 'creat...
# 4  {'id': 'pw0BxLrUQ9ydCyqaP4OJLFSuucTZY', 'creat...
# 5  {'id': 'Ng9SVs6bKIwNOTr5i0PxBlF3xCQZY', 'creat...
# 6  {'id': 'FWYdT4ICNQLjbjYN3CIFoQinCh8YY', 'creat...
# 7  {'id': 'rRM7KKQc99UAduir98Uq91719SdZY', 'creat...

# %%
# flatout the json file
df_nested = pd.json_normalize(respond_json, record_path=['payments'])
df_nested.head(5)
# Out:
#                               id                created_at  \
# 0  1YH4A3G2vyv2ejVP419qN4LJ0jPZY  2021-05-06T17:18:36.496Z
# 1  ZcOXsHdFQYe6mscHrfI1n9XVTp5YY  2021-05-06T17:17:28.993Z
# 2  tcbG7J79thsEQuYsts0npMcl3MGZY  2021-05-06T17:15:47.423Z
# 3  zDxcvcbsI4jHuGpiIOehkwWGfbMZY  2021-04-22T02:51:31.858Z
# 4  pw0BxLrUQ9ydCyqaP4OJLFSuucTZY  2021-04-21T23:53:21.668Z
#
#                  updated_at     status delay_duration source_type  \
# 0  2021-05-06T17:18:37.487Z  COMPLETED         PT168H        CARD
# 1  2021-05-06T17:17:29.621Z  COMPLETED         PT168H        CARD
# 2  2021-05-06T17:15:49.002Z  COMPLETED         PT168H        CARD
# 3  2021-04-22T02:51:33.210Z  COMPLETED         PT168H        CARD
# 4  2021-04-21T23:53:22.726Z  COMPLETED         PT168H        CARD
#
#      location_id                      order_id  \
# 0  LS2TXDC8CSGZN  BH7O6aT82bAeUQE2jaoTvI5AJf4F
# 1  LS2TXDC8CSGZN  B3xLPvknK07igJsWtnXkVgYuag4F
# 2  LS2TXDC8CSGZN  Bhcu5ofCoDxPz8OewOIjWSeYnd4F
# ...

# %%
df_nested.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 38 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   id                                                8 non-null      object
#  1   created_at                                        8 non-null      object
#  2   updated_at                                        8 non-null      object
#  3   status                                            8 non-null      object
#  4   delay_duration                                    8 non-null      object
#  5   source_type                                       8 non-null      object
#  6   location_id                                       8 non-null      object
#  7   order_id                                          8 non-null      object
#  8   processing_fee                                    8 non-null      object
# ...

# %%
# print out the result I assume mostly important
df_important = df_nested[['created_at', 'updated_at', 'note', 'total_money.amount', 'total_money.currency']]
df_important.head(5)
# Out:
#                  created_at                updated_at  \
# 0  2021-05-06T17:18:36.496Z  2021-05-06T17:18:37.487Z
# 1  2021-05-06T17:17:28.993Z  2021-05-06T17:17:29.621Z
# 2  2021-05-06T17:15:47.423Z  2021-05-06T17:15:49.002Z
# 3  2021-04-22T02:51:31.858Z  2021-04-22T02:51:33.210Z
# 4  2021-04-21T23:53:21.668Z  2021-04-21T23:53:22.726Z
#
#                                                 note  total_money.amount  \
# 0                                         cappuccino                 436
# 1                                               chai                3608
# 2                                              latte                2000
# 3                                         some drink                1000
# 4  Toasted Coconut Latte (16oz ICED) - beachy, su...                 356
#
#   total_money.currency
# 0                  USD
# 1                  USD
# 2                  USD
# 3                  USD
# 4                  USD

# %%
# a step back: extract transaction data from API

# %%
# using requests
import requests

headers = {
    'Authorization': 'Bearer EAAAEHQcY0r_9g8-cUBlEibgH-eAzbL1piZWERxPc9qbrmSdIU8-3Dj-H6rTtdkr',
    'Content-Type': 'application/json',
}

params = (
    ('begin_time', '2021-01-02T00:00:01.007Z'),
    ('end_time', '2021-06-02T00:00:01.007Z'),
)

# response = requests.get('https://connect.squareupsandbox.com/v2/payments', headers=headers, params=params)
response = requests.get('https://connect.squareupsandbox.com/v2/payments?begin_time=2021-01-02T00%3A00%3A01.007Z&end_time=2021-06-02T00%3A00%3A01.007Z', headers=headers)

# original
"""
curl "https://connect.squareupsandbox.com/v2/payments?begin_time=2021-01-02T00%3A00%3A01.007Z&end_time=2021-06-02T00%3A00%3A01.007Z" \
  -H 'Authorization: Bearer EAAAEHQcY0r_9g8-cUBlEibgH-eAzbL1piZWERxPc9qbrmSdIU8-3Dj-H6rTtdkr' \
  -H 'Content-Type: application/json'
"""
# curl -> python request website: https://curl.trillworks.com/
# Out:
# '\ncurl "https://connect.squareupsandbox.com/v2/payments?begin_time=2021-01-02T00%3A00%3A01.007Z&end_time=2021-06-02T00%3A00%3A01.007Z"   -H \'Authorization: Bearer EAAAEHQcY0r_9g8-cUBlEibgH-eAzbL1piZWERxPc9qbrmSdIU8-3Dj-H6rTtdkr\'   -H \'Content-Type: application/json\'\n'

# %%
response
# Out:
# <Response [200]>

# %%
# this is also a good site
# https://reqbin.com/req/python/c-xgafmluu/convert-curl-to-python-requests
import requests
from requests.structures import CaseInsensitiveDict

url = "https://connect.squareupsandbox.com/v2/payments?begin_time=2021-01-02T00%3A00%3A01.007Z&end_time=2021-06-02T00%3A00%3A01.007Z"

headers = CaseInsensitiveDict()
headers["Authorization"] = "Bearer EAAAEHQcY0r_9g8-cUBlEibgH-eAzbL1piZWERxPc9qbrmSdIU8-3Dj-H6rTtdkr"
headers["Content-Type"] = "application/json"


resp = requests.get(url, headers=headers)

print(resp.status_code)
# Out:
# 200

# %%
# beautifulsoup parsing
# not necessary here
from bs4 import BeautifulSoup as bs
html_file = bs(resp.text, "html.parser")
html_file.prettify()
# Out:
# '{"payments": [{"id": "3fyilaoXv4wcj6THMVozVivRihaZY","created_at": "2021-05-17T05:19:44.895Z","updated_at": "2021-05-17T05:23:30.731Z","amount_money": {"amount": 245,"currency": "USD"},"status": "CANCELED","delay_duration": "PT168H","source_type": "CARD","card_details": {"status": "VOIDED","card": {"card_brand": "VISA","last_4": "5858","exp_month": 5,"exp_year": 2023,"fingerprint": "sq-1-fTOnkJlCWUDk8h2haVmxCvTGSUXUQBBaioU14U__LnB9CPOIOLqSD22dlXxOB-fbAg","card_type": "DEBIT","prepaid_type": "NOT_PREPAID","bin": "453275"},"entry_method": "KEYED","cvv_status": "CVV_ACCEPTED","avs_status": "AVS_ACCEPTED","statement_description": "SQ *DEFAULT TEST ACCOUNT","card_payment_timeline": {"authorized_at": "2021-05-17T05:19:45.004Z","voided_at": "2021-05-17T05:23:29.448Z"}},"location_id": "LS2TXDC8CSGZN","order_id": "ZVqr1UIeV62EJW78VRRE3tUute4F","risk_evaluation": {"created_at": "2021-05-17T05:19:45.004Z","risk_level": "NORMAL"},"note": "Brief description","total_money": {"amount": 245,"curren
# ...

# %%
# we already know the response is in json
res_df = pd.DataFrame(eval(resp.text))
res_df.head()
# Out:
#                                             payments
# 0  {'id': '3fyilaoXv4wcj6THMVozVivRihaZY', 'creat...
# 1  {'id': 'jRGp55QH138wzyPyQ1c2RddAwZcZY', 'creat...
# 2  {'id': 'DnlxEym8g2GHdYb1iqUWQFjgIDVZY', 'creat...
# 3  {'id': 'FWaImvWbKPwLo4Kb4Xt47njdorFZY', 'creat...
# 4  {'id': 'XD8SNSxKJ9kt78sjvF2hQRUdBaMZY', 'creat...

# %%
# now we are back to what we are familier with (exactly the same way we demonstrate at the beginning)
df_flat = pd.json_normalize(json.loads(resp.text), record_path="payments")
df_flat.head()
df_flat[['id','created_at', 'updated_at', 'note', 'total_money.amount', 'total_money.currency']].head()
# Out:
#                               id                created_at  \
# 0  3fyilaoXv4wcj6THMVozVivRihaZY  2021-05-17T05:19:44.895Z
# 1  jRGp55QH138wzyPyQ1c2RddAwZcZY  2021-05-17T04:42:53.593Z
# 2  DnlxEym8g2GHdYb1iqUWQFjgIDVZY  2021-05-17T03:47:54.218Z
# 3  FWaImvWbKPwLo4Kb4Xt47njdorFZY  2021-05-17T03:00:43.243Z
# 4  XD8SNSxKJ9kt78sjvF2hQRUdBaMZY  2021-05-17T03:00:03.154Z
#
#                  updated_at               note  total_money.amount  \
# 0  2021-05-17T05:23:30.731Z  Brief description                 245
# 1  2021-05-17T04:42:55.321Z  Brief description                 245
# 2  2021-05-17T03:47:54.939Z  Brief description                 245
# 3  2021-05-17T03:00:44.160Z  Brief description                 200
# 4  2021-05-17T03:00:03.263Z  Brief description                 200
#
#   total_money.currency
# 0                  USD
# 1                  USD
# 2                  USD
# 3                  USD
# 4                  USD
