# %%
from square.client import Client
import pandas as pd
import json

# %%
## Add this to the first block in your note book
import uuid
from IPython.core.display import display, HTML

import json

class RenderJSON(object):
    def __init__(self, json_data):
        if isinstance(json_data, dict):
            self.json_str = json.dumps(json_data)
        else:
            self.json_str = json_data
        self.uuid = str(uuid.uuid4())
        # This line is missed out in most of the versions of this script across the web, it is essential for this to work interleaved with print statements
        self._ipython_display_()
        
    def _ipython_display_(self):
        display(HTML('<div id="{}" style="height: auto; width:100%;"></div>'.format(self.uuid)))
        display(HTML("""<script>
        require(["https://rawgit.com/caldwell/renderjson/master/renderjson.js"], function() {
          renderjson.set_show_to_level(1)
          document.getElementById('%s').appendChild(renderjson(%s))
        });</script>
        """ % (self.uuid, self.json_str)))

# Since this is copy-pasted wrongly(mostly) at a lot of places across the web, i'm putting the fixed, updated version here, mainly for self-reference


## To use this function, call this, this now works even when you have a print statement before or after the RenderJSON call
# RenderJSON(your_json)
RenderJSON(json.loads(result.text))

# %%
sandbox_token = "EAAAECCddSeDNsweJXdjNVux8FTfVgMUXAroCh7VcOuoPlgjYb7MrkULH8DZrZmJ"

client = Client(
    access_token = sandbox_token,
    environment='sandbox',
)

# %%
production_token = "EAAAEfz2MN9eAPDmBIuiC4ZT2ulokQjU3JIKHtBxm-R4TCAZgh4QWM2Svb0pRQNH"
client = Client(
    access_token = production_token,
    environment='production',
)

result = client.payments.list_payments(
  begin_time = "2021-01-01T00:00:00.007Z",
  end_time = "2021-06-01T00:00:00.007Z"
)

if result.is_success():
  RenderJSON(json.loads(result.text))
elif result.is_error():
  print(result.errors)
# Out:
# <div id="9206c9ae-6e6d-465d-9ca7-026317f2593f" style="height: auto; width:100%;"></div>
# <script>
#         require(["https://rawgit.com/caldwell/renderjson/master/renderjson.js"], function() {
#           renderjson.set_show_to_level(1)
# ...

# %%
result = client.payments.get_payment(
  payment_id = "909TXFi142qGDSQu9IU882pZuaB"
)

if result.is_success():
  RenderJSON(json.loads(result.text))
elif result.is_error():
  print(result.errors)
# Out:
# <div id="dd217c39-0a2a-4a55-826a-d9400546860b" style="height: auto; width:100%;"></div>
# <script>
#         require(["https://rawgit.com/caldwell/renderjson/master/renderjson.js"], function() {
#           renderjson.set_show_to_level(1)
#           document.getElementById('dd217c39-0a2a-4a55-826a-d9400546860b').appendChild(renderjson({"payment": {"id": "909TXFi142qGDSQu9IU882pZuaB", "created_at": "2021-05-26T03:19:43.469Z", "amount_money": {"amount": 4, "currency": "USD"}, "status": "COMPLETED", "source_type": "CASH", "location_id": "L242FZF9SMX3M", "order_id": "eNoEUg2BhPI7WB9I1msBjZyeV", "total_money": {"amount": 4, "currency": "USD"}, "cash_details": {"buyer_supplied_money": {"amount": 4, "currency": "USD"}, "change_back_money": {"amount": 0, "currency": "USD"}}, "receipt_number": "909T", "receipt_url": "https://squareup.com/receipt/preview/909TXFi142qGDSQu9IU882pZuaB", "version_token": "LG5miEQWifStLMlNrlEuDdjFegGPRtu4EJJegj22PYa6o"}}))
#         });</script>

# %%
result = client.orders.retrieve_order(
  order_id = 'eNoEUg2BhPI7WB9I1msBjZyeV'
)


if result.is_success():
  RenderJSON(json.loads(result.text))
elif result.is_error():
  print(result.errors)
# Out:
# <div id="05c48590-30ff-4a1f-b875-3febfc9f692f" style="height: auto; width:100%;"></div>
# <script>
#         require(["https://rawgit.com/caldwell/renderjson/master/renderjson.js"], function() {
#           renderjson.set_show_to_level(1)
# ...

# %%
result = client.orders.retrieve_order(
  order_id = 'IqWDT5GyFYRFKzzD6KrhwCyeV'
)


if result.is_success():
  RenderJSON(json.loads(result.text))
elif result.is_error():
  print(result.errors)
# Out:
# <div id="8ca1b51d-3aa6-480c-bd76-a4c3e8fca7f5" style="height: auto; width:100%;"></div>
# <script>
#         require(["https://rawgit.com/caldwell/renderjson/master/renderjson.js"], function() {
#           renderjson.set_show_to_level(1)
# ...

# %%
result = client.catalog.retrieve_catalog_object(
  object_id = "6FJBUKNCMN4OWEKQKK77IVYH",
  include_related_objects = False
)

if result.is_success():
  print(result.body)
elif result.is_error():
  print(result.errors)
# Out:
# {'object': {'id': '6FJBUKNCMN4OWEKQKK77IVYH', 'is_deleted': False, 'item_variation_data': {'item_id': 'EPDUTEFNLZKWZHSWAFLLOUCS', 'item_option_values': [{'item_option_id': 'QLA5ZQQ7HRQRU6ASNL37O6ZT', 'item_option_value_id': 'GAEOHKJ3ANVGRM2LQMVO247A'}, {'item_option_id': '27OPF4USPPXHTBSFZTS7XFC2', 'item_option_value_id': 'YRQHNGYYZH4IMJBKZWDW5BZ3'}, {'item_option_id': 'QVQBHHJUOJZ5MG3WQBPRVYO6', 'item_option_value_id': 'TS4LINPTKZUNM223HH4CHDOO'}], 'name': 'option holder 1-A, option holder 2-A, option holder 3-A', 'ordinal': 0, 'pricing_type': 'VARIABLE_PRICING'}, 'present_at_all_locations': True, 'type': 'ITEM_VARIATION', 'updated_at': '2021-05-24T19:20:47.721Z', 'version': 1621884047721}}

# %%
df_flat = pd.DataFrame.from_dict(result.body["object"])
df_flat.head()
# Out:
#                                           id  is_deleted  \
# item_id             6FJBUKNCMN4OWEKQKK77IVYH       False
# item_option_values  6FJBUKNCMN4OWEKQKK77IVYH       False
# name                6FJBUKNCMN4OWEKQKK77IVYH       False
# ordinal             6FJBUKNCMN4OWEKQKK77IVYH       False
# pricing_type        6FJBUKNCMN4OWEKQKK77IVYH       False
#
#                                                   item_variation_data  \
# item_id                                      EPDUTEFNLZKWZHSWAFLLOUCS
# item_option_values  [{'item_option_id': 'QLA5ZQQ7HRQRU6ASNL37O6ZT'...
# name                option holder 1-A, option holder 2-A, option h...
# ordinal                                                             0
# pricing_type                                         VARIABLE_PRICING
#
#                     present_at_all_locations            type  \
# item_id                                 True  ITEM_VARIATION
# item_option_values                      True  ITEM_VARIATION
# ...

# %%
# df_flat = pd.json_normalize(json.loads(result.text), record_path="object")
# df_flat.head()
json.dumps(json.loads(result.text), indent=4, sort_keys=True)
# Out:
# '{\n    "object": {\n        "id": "6FJBUKNCMN4OWEKQKK77IVYH",\n        "is_deleted": false,\n        "item_variation_data": {\n            "item_id": "EPDUTEFNLZKWZHSWAFLLOUCS",\n            "item_option_values": [\n                {\n                    "item_option_id": "QLA5ZQQ7HRQRU6ASNL37O6ZT",\n                    "item_option_value_id": "GAEOHKJ3ANVGRM2LQMVO247A"\n                },\n                {\n                    "item_option_id": "27OPF4USPPXHTBSFZTS7XFC2",\n                    "item_option_value_id": "YRQHNGYYZH4IMJBKZWDW5BZ3"\n                },\n                {\n                    "item_option_id": "QVQBHHJUOJZ5MG3WQBPRVYO6",\n                    "item_option_value_id": "TS4LINPTKZUNM223HH4CHDOO"\n                }\n            ],\n            "name": "option holder 1-A, option holder 2-A, option holder 3-A",\n            "ordinal": 0,\n            "pricing_type": "VARIABLE_PRICING"\n        },\n        "present_at_all_locations": true,\n        "type": "ITEM_
# ...

# %%
print(json.dumps(json.loads(result.text), indent=4, sort_keys=True))
# Out:
# {
#     "object": {
#         "id": "6FJBUKNCMN4OWEKQKK77IVYH",
#         "is_deleted": false,
#         "item_variation_data": {
#             "item_id": "EPDUTEFNLZKWZHSWAFLLOUCS",
#             "item_option_values": [
#                 {
#                     "item_option_id": "QLA5ZQQ7HRQRU6ASNL37O6ZT",
#                     "item_option_value_id": "GAEOHKJ3ANVGRM2LQMVO247A"
#                 },
#                 {
#                     "item_option_id": "27OPF4USPPXHTBSFZTS7XFC2",
#                     "item_option_value_id": "YRQHNGYYZH4IMJBKZWDW5BZ3"
#                 },
#                 {
#                     "item_option_id": "QVQBHHJUOJZ5MG3WQBPRVYO6",
#                     "item_option_value_id": "TS4LINPTKZUNM223HH4CHDOO"
#                 }
#             ],
#             "name": "option holder 1-A, option holder 2-A, option holder 3-A",
#             "ordinal": 0,
#             "pricing_type": "VARIABLE_PRICING"
#         },
#         "present_at_all_locations": true,
# ...

# %%
result = client.catalog.retrieve_catalog_object(
  object_id = "6FJBUKNCMN4OWEKQKK77IVYH",
  include_related_objects = True
)

print(json.dumps(json.loads(result.text), indent=4, sort_keys=True))
# Out:
# {
#     "object": {
#         "id": "6FJBUKNCMN4OWEKQKK77IVYH",
#         "is_deleted": false,
#         "item_variation_data": {
#             "item_id": "EPDUTEFNLZKWZHSWAFLLOUCS",
#             "item_option_values": [
#                 {
#                     "item_option_id": "QLA5ZQQ7HRQRU6ASNL37O6ZT",
#                     "item_option_value_id": "GAEOHKJ3ANVGRM2LQMVO247A"
#                 },
#                 {
#                     "item_option_id": "27OPF4USPPXHTBSFZTS7XFC2",
#                     "item_option_value_id": "YRQHNGYYZH4IMJBKZWDW5BZ3"
#                 },
#                 {
#                     "item_option_id": "QVQBHHJUOJZ5MG3WQBPRVYO6",
#                     "item_option_value_id": "TS4LINPTKZUNM223HH4CHDOO"
#                 }
#             ],
#             "name": "option holder 1-A, option holder 2-A, option holder 3-A",
#             "ordinal": 0,
#             "pricing_type": "VARIABLE_PRICING"
#         },
#         "present_at_all_locations": true,
# ...

# %%
# Out:
# <div id="998f8cf0-0f4d-4618-917f-c8985ba3347d" style="height: auto; width:100%;"></div>
# <script>
#         require(["https://rawgit.com/caldwell/renderjson/master/renderjson.js"], function() {
#           renderjson.set_show_to_level(1)
# ...

# %%
# object item

result = client.catalog.retrieve_catalog_object(
  object_id = "EPDUTEFNLZKWZHSWAFLLOUCS",
  include_related_objects = True
)
RenderJSON(json.loads(result.text))
# Out:
# <div id="81136ee6-9369-4fe4-a61b-1e2a2e861ab4" style="height: auto; width:100%;"></div>
# <script>
#         require(["https://rawgit.com/caldwell/renderjson/master/renderjson.js"], function() {
#           renderjson.set_show_to_level(1)
# ...

# %%
result = client.catalog.upsert_catalog_object(
  body = {
    "idempotency_key": "f7503641-57c5-4ad7-9c99-8286b91b1c78",
    "object": {
      "type": "ITEM",
      "id": "#00002",
      "item_data": {
        "name": "item_test_3",
        "description": "description of item test 3",
        "category_id": "JBKHCQPV2MZL2LLDKWKROQBA",
        "product_type": "REGULAR",
        "item_options": [
          {
            "item_option_id": "QLA5ZQQ7HRQRU6ASNL37O6ZT"
          }
        ]
      },
      "item_option_data": {
        "values": [
          {
            "type": "ITEM_OPTION_VAL",
            "id": "GAEOHKJ3ANVGRM2LQMVO247A",
            "item_variation_data": {
              "item_id": "EPDUTEFNLZKWZHSWAFLLOUCS",
              "item_option_values": [
                {
                  "item_option_id": "QLA5ZQQ7HRQRU6ASNL37O6ZT",
                  "item_option_value_id": "GAEOHKJ3ANVGRM2LQMVO247A"
                }
              ]
            },
            "item_option_value_data": {
              "item_option_id": "QLA5ZQQ7HRQRU6ASNL37O6ZT"
            }
          }
        ]
      }
    }
  }
)

if result.is_success():
  print(result.body)
elif result.is_error():
  print(result.errors)
# Out:
# <div id="f26bfbad-5ccb-4da7-ba0b-013ef9ecc3d8" style="height: auto; width:100%;"></div>
# <script>
#         require(["https://rawgit.com/caldwell/renderjson/master/renderjson.js"], function() {
#           renderjson.set_show_to_level(1)
# ...

# %%
result = client.catalog.retrieve_catalog_object(
  object_id = "QVQBHHJUOJZ5MG3WQBPRVYO6",
  include_related_objects = True
)
RenderJSON(json.loads(result.text))
# Out:
# <div id="cc19e9f1-4e76-48d1-8271-407ed8d617b8" style="height: auto; width:100%;"></div>
# <script>
#         require(["https://rawgit.com/caldwell/renderjson/master/renderjson.js"], function() {
#           renderjson.set_show_to_level(1)
# ...

# %%
print(uuid.uuid1())
# Out:
# 3ad72cbe-bd8f-11eb-b141-818179438128

# %%
# tutorial
idem_key = str(uuid.uuid1())
result = client.catalog.upsert_catalog_object(
  body = {
    "idempotency_key": idem_key,
    "object": {
      "type": "ITEM",
      "id": "#shirt",
      "item_data": {
        "name": "Shirt",
        "description": "Shirt",
        "variations": [
          {
            "type": "ITEM_VARIATION",
            "id": "#shirt_small_red",
            "item_variation_data": {
              "name": "Small red shirt",
              "pricing_type": "FIXED_PRICING",
              "price_money": {
                "amount": 2500,
                "currency": "USD"
              }
            }
          },
          {
            "type": "ITEM_VARIATION",
            "id": "#shirt_medium_red",
            "item_variation_data": {
              "name": "Medium red shirt",
              "pricing_type": "FIXED_PRICING",
              "price_money": {
                "amount": 3000,
                "currency": "USD"
              }
            }
          },
          {
            "type": "ITEM_VARIATION",
            "id": "#shirt_large_red",
            "item_variation_data": {
              "name": "Large red shirt",
              "pricing_type": "FIXED_PRICING",
              "price_money": {
                "amount": 3500,
                "currency": "USD"
              }
            }
          },
          {
            "type": "ITEM_VARIATION",
            "id": "#shirt_small_blue",
            "item_variation_data": {
              "name": "Small blue shirt",
              "pricing_type": "FIXED_PRICING",
              "price_money": {
                "amount": 2500,
                "currency": "USD"
              }
            }
          },
          {
            "type": "ITEM_VARIATION",
            "id": "#shirt_medium_blue",
            "item_variation_data": {
              "name": "Medium blue shirt",
              "pricing_type": "FIXED_PRICING",
              "price_money": {
                "amount": 3000,
                "currency": "USD"
              }
            }
          },
          {
            "type": "ITEM_VARIATION",
            "id": "#shirt_large_blue",
            "item_variation_data": {
              "name": "Large blue shirt",
              "pricing_type": "FIXED_PRICING",
              "price_money": {
                "amount": 3500,
                "currency": "USD"
              }
            }
          }
        ],
        "product_type": "REGULAR"
      }
    }
  }
)

if result.is_success():
  print(result.body)
elif result.is_error():
  print(result.errors)
# Out:
# {'catalog_object': {'id': 'LLT7C4U3OXG4XBKX7FO47NRP', 'is_deleted': False, 'item_data': {'description': 'Shirt', 'name': 'Shirt', 'product_type': 'REGULAR', 'variations': [{'id': 'IBGIY25V6TAHUYWXT5OEHHAN', 'is_deleted': False, 'item_variation_data': {'item_id': 'LLT7C4U3OXG4XBKX7FO47NRP', 'name': 'Small red shirt', 'ordinal': 0, 'price_money': {'amount': 2500, 'currency': 'USD'}, 'pricing_type': 'FIXED_PRICING'}, 'present_at_all_locations': True, 'type': 'ITEM_VARIATION', 'updated_at': '2021-05-25T20:57:49.957Z', 'version': 1621976269957}, {'id': 'N4I57SLF6MZDHMP7Q2FT5D6O', 'is_deleted': False, 'item_variation_data': {'item_id': 'LLT7C4U3OXG4XBKX7FO47NRP', 'name': 'Medium red shirt', 'ordinal': 1, 'price_money': {'amount': 3000, 'currency': 'USD'}, 'pricing_type': 'FIXED_PRICING'}, 'present_at_all_locations': True, 'type': 'ITEM_VARIATION', 'updated_at': '2021-05-25T20:57:49.957Z', 'version': 1621976269957}, {'id': 'CNXOIIKS3OEIJKWJ4MDESEHC', 'is_deleted': False, 'item_variation_dat
# ...

# %%
body = {
    "idempotency_key": idem_key,
    "object": {
      "type": "ITEM",
      "id": "#shirt",
      "item_data": {
        "name": "Shirt",
        "description": "Shirt",
        "variations": [
          {
            "type": "ITEM_VARIATION",
            "id": "#shirt_small_red",
            "item_variation_data": {
              "name": "Small red shirt",
              "pricing_type": "FIXED_PRICING",
              "price_money": {
                "amount": 2500,
                "currency": "USD"
              }
            }
          },
          {
            "type": "ITEM_VARIATION",
            "id": "#shirt_medium_red",
            "item_variation_data": {
              "name": "Medium red shirt",
              "pricing_type": "FIXED_PRICING",
              "price_money": {
                "amount": 3000,
                "currency": "USD"
              }
            }
          },
          {
            "type": "ITEM_VARIATION",
            "id": "#shirt_large_red",
            "item_variation_data": {
              "name": "Large red shirt",
              "pricing_type": "FIXED_PRICING",
              "price_money": {
                "amount": 3500,
                "currency": "USD"
              }
            }
          },
          {
            "type": "ITEM_VARIATION",
            "id": "#shirt_small_blue",
            "item_variation_data": {
              "name": "Small blue shirt",
              "pricing_type": "FIXED_PRICING",
              "price_money": {
                "amount": 2500,
                "currency": "USD"
              }
            }
          },
          {
            "type": "ITEM_VARIATION",
            "id": "#shirt_medium_blue",
            "item_variation_data": {
              "name": "Medium blue shirt",
              "pricing_type": "FIXED_PRICING",
              "price_money": {
                "amount": 3000,
                "currency": "USD"
              }
            }
          },
          {
            "type": "ITEM_VARIATION",
            "id": "#shirt_large_blue",
            "item_variation_data": {
              "name": "Large blue shirt",
              "pricing_type": "FIXED_PRICING",
              "price_money": {
                "amount": 3500,
                "currency": "USD"
              }
            }
          }
        ],
        "product_type": "REGULAR"
      }
    }
  }
json_display = json.dumps(dict(body))
RenderJSON(json.dumps(dict(body)))
# Out:
# <div id="5c24b7c5-1cd2-4d8f-a4de-6565e9b8a6d1" style="height: auto; width:100%;"></div>
# <script>
#         require(["https://rawgit.com/caldwell/renderjson/master/renderjson.js"], function() {
#           renderjson.set_show_to_level(1)
# ...

# %%
# create item variations with item options
idem_key = str(uuid.uuid1())
body = {
"idempotency_key": idem_key,
"batches": [
  {
    "objects": [
      {
        "type": "ITEM_OPTION",
        "id": "#item_option_color",
        "item_option_data": {
          "name": "COLOR_OPTIONS",
          "values": [
            {
              "type": "ITEM_OPTION_VAL",
              "id": "#item_option_value_color_red",
              "item_option_value_data": {
                "name": "RED"
              }
            },
            {
              "type": "ITEM_OPTION_VAL",
              "id": "#item_option_value_color_blue",
              "item_option_value_data": {
                "name": "Blue"
              }
            }
          ]
        }
      },
      {
        "type": "ITEM_OPTION",
        "id": "#item_option_size",
        "item_option_data": {
          "name": "SIZE_OPTIONS",
          "values": [
            {
              "type": "ITEM_OPTION_VAL",
              "id": "#item_option_value_size_small",
              "item_option_value_data": {
                "name": "Small"
              }
            },
            {
              "type": "ITEM_OPTION_VAL",
              "id": "#item_option_value_size_medium",
              "item_option_value_data": {
                "name": "Medium"
              }
            },
            {
              "type": "ITEM_OPTION_VAL",
              "id": "#item_option_value_size_large",
              "item_option_value_data": {
                "name": "Large"
              }
            }
          ]
        }
      },
      {
        "type": "ITEM",
        "id": "#item",
        "item_data": {
          "name": "Shirt",
          "variations": [
            {
              "type": "ITEM_VARIATION",
              "id": "#item_variation_small_red",
              "item_variation_data": {
                "pricing_type": "FIXED_PRICING",
                "price_money": {
                  "amount": 2500,
                  "currency": "USD"
                },
                "item_option_values": [
                  {
                    "item_option_id": "#item_option_size",
                    "item_option_value_id": "#item_option_value_size_small"
                  },
                  {
                    "item_option_id": "#item_option_color",
                    "item_option_value_id": "#item_option_value_color_red"
                  }
                ]
              }
            },
            {
              "type": "ITEM_VARIATION",
              "id": "#item_variation_medium_red",
              "item_variation_data": {
                "pricing_type": "FIXED_PRICING",
                "price_money": {
                  "amount": 3000,
                  "currency": "USD"
                },
                "item_option_values": [
                  {
                    "item_option_id": "#item_option_size",
                    "item_option_value_id": "#item_option_value_size_medium"
                  },
                  {
                    "item_option_id": "#item_option_color",
                    "item_option_value_id": "#item_option_value_color_red"
                  }
                ]
              }
            },
            {
              "type": "ITEM_VARIATION",
              "id": "#item_variation_large_red",
              "item_variation_data": {
                "pricing_type": "FIXED_PRICING",
                "price_money": {
                  "amount": 3500,
                  "currency": "USD"
                },
                "item_option_values": [
                  {
                    "item_option_id": "#item_option_size",
                    "item_option_value_id": "#item_option_value_size_large"
                  },
                  {
                    "item_option_id": "#item_option_color",
                    "item_option_value_id": "#item_option_value_color_red"
                  }
                ]
              }
            },
            {
              "type": "ITEM_VARIATION",
              "id": "#item_variation_small_blue",
              "item_variation_data": {
                "pricing_type": "FIXED_PRICING",
                "price_money": {
                  "amount": 2500,
                  "currency": "USD"
                },
                "item_option_values": [
                  {
                    "item_option_id": "#item_option_size",
                    "item_option_value_id": "#item_option_value_size_small"
                  },
                  {
                    "item_option_id": "#item_option_color",
                    "item_option_value_id": "#item_option_value_color_blue"
                  }
                ]
              }
            },
            {
              "type": "ITEM_VARIATION",
              "id": "#item_variation_medium_blue",
              "item_variation_data": {
                "pricing_type": "FIXED_PRICING",
                "price_money": {
                  "amount": 3000,
                  "currency": "USD"
                },
                "item_option_values": [
                  {
                    "item_option_id": "#item_option_size",
                    "item_option_value_id": "#item_option_value_size_medium"
                  },
                  {
                    "item_option_id": "#item_option_color",
                    "item_option_value_id": "#item_option_value_color_blue"
                  }
                ]
              }
            },
            {
              "type": "ITEM_VARIATION",
              "id": "#item_variation_large_blue",
              "item_variation_data": {
                "pricing_type": "FIXED_PRICING",
                "price_money": {
                  "amount": 3500,
                  "currency": "USD"
                },
                "item_option_values": [
                  {
                    "item_option_id": "#item_option_size",
                    "item_option_value_id": "#item_option_value_size_large"
                  },
                  {
                    "item_option_id": "#item_option_color",
                    "item_option_value_id": "#item_option_value_color_blue"
                  }
                ]
              }
            }
          ],
          "product_type": "REGULAR",
          "item_options": [
            {
              "item_option_id": "#item_option_size"
            },
            {
              "item_option_id": "#item_option_color"
            }
          ]
        }
      }
    ]
  }
]
}
    
result = client.catalog.batch_upsert_catalog_objects(body)

if result.is_success():
  print(result.body)
elif result.is_error():
  print(result.errors)
# Out:
# {'id_mappings': [{'client_object_id': '#item_option_color', 'object_id': 'OIGNZFFYOOTUJL43ENK36H2I'}, {'client_object_id': '#item_option_size', 'object_id': 'OSWYNPBW3EMRSQMWZMSDSZ2N'}, {'client_object_id': '#item', 'object_id': 'KNANBJUSA6GQMYZSAONESLH4'}, {'client_object_id': '#item_option_value_color_red', 'object_id': 'K6XJK5RW7UAI56D4MSZRR5M2'}, {'client_object_id': '#item_option_value_color_blue', 'object_id': 'WITVXF2BT2PJRLRI3PZSJXTU'}, {'client_object_id': '#item_option_value_size_small', 'object_id': '5MWSIZGPUGBRNODVLKDNFSUU'}, {'client_object_id': '#item_option_value_size_medium', 'object_id': 'TWAZK3ISIWQFUA4P2J7IN6JB'}, {'client_object_id': '#item_option_value_size_large', 'object_id': 'TW2Y3ZGWMQAXGPRDEAYWALPV'}, {'client_object_id': '#item_variation_small_red', 'object_id': 'TEPVBK5OSXRQUJ3ERNSH6ALV'}, {'client_object_id': '#item_variation_medium_red', 'object_id': '2P2HPGHTUG4JB77GT6PFJU3K'}, {'client_object_id': '#item_variation_large_red', 'object_id': '4WLQMAP4WIS
# ...

# %%
RenderJSON(json.dumps(dict(body)))
# Out:
# <div id="37fd7569-a5dc-4be6-8984-a907c11cc2c0" style="height: auto; width:100%;"></div>
# <script>
#         require(["https://rawgit.com/caldwell/renderjson/master/renderjson.js"], function() {
#           renderjson.set_show_to_level(1)
# ...

# %%
result = client.catalog.search_catalog_objects(
  body = {
    "query": {
      "text_query": {
        "keywords": [
          "Small, RED"
        ]
      }
    }
  }
)

if result.is_success():
#   print(result.body)
    RenderJSON(json.loads(result.text))
elif result.is_error():
  print(result.errors)
# Out:
# <div id="2fa14eb5-f36f-42fd-9677-e14b2b750a76" style="height: auto; width:100%;"></div>
# <script>
#         require(["https://rawgit.com/caldwell/renderjson/master/renderjson.js"], function() {
#           renderjson.set_show_to_level(1)
# ...

# %%
result = client.catalog.search_catalog_objects(
  body = {
    "query": {
      "text_query": {
        "keywords": [
          "Small red shirt"
        ]
      }
    }
  }
)

if result.is_success():
#   print(result.body)
    RenderJSON(json.loads(result.text))
elif result.is_error():
  print(result.errors)
# Out:
# <div id="682aa3cc-769e-4189-a013-9bb2cdcf8af8" style="height: auto; width:100%;"></div>
# <script>
#         require(["https://rawgit.com/caldwell/renderjson/master/renderjson.js"], function() {
#           renderjson.set_show_to_level(1)
# ...

# %%
RenderJSON(json.loads(result.text))
# Out:
# <div id="c7a58de7-4d8e-4dd9-97b3-d1d7ed54bb39" style="height: auto; width:100%;"></div>
# <script>
#         require(["https://rawgit.com/caldwell/renderjson/master/renderjson.js"], function() {
#           renderjson.set_show_to_level(1)
# ...

# %%
result = client.catalog.search_catalog_objects(
  body = {
    "query": {
      "text_query": {
        "keywords": [
          "category"
        ]
      }
    }
  }
)

if result.is_success():
#   print(result.body)
    RenderJSON(json.loads(result.text))
elif result.is_error():
  print(result.errors)
# Out:
# <div id="f17bf8fa-f370-4767-87a8-30625d0421e1" style="height: auto; width:100%;"></div>
# <script>
#         require(["https://rawgit.com/caldwell/renderjson/master/renderjson.js"], function() {
#           renderjson.set_show_to_level(1)
#           document.getElementById('f17bf8fa-f370-4767-87a8-30625d0421e1').appendChild(renderjson({"objects": [{"type": "CATEGORY", "id": "JBKHCQPV2MZL2LLDKWKROQBA", "updated_at": "2021-05-24T17:45:03.521Z", "version": 1621878303521, "is_deleted": false, "present_at_all_locations": true, "category_data": {"name": "category holder"}}, {"type": "CATEGORY", "id": "VSPDAKFXEBSJ7E4O2MMWFAVD", "updated_at": "2021-05-24T17:45:34.455Z", "version": 1621878334455, "is_deleted": false, "present_at_all_locations": true, "category_data": {"name": "category holder 2"}}], "latest_time": "2021-05-25T23:12:39.45Z"}))
#         });</script>

# %%
# create item variations with item options
# specify variation name
idem_key = str(uuid.uuid1())
body = {
"idempotency_key": idem_key,
"batches": [
  {
    "objects": [
#       {
#         "type": "ITEM_OPTION",
#         "id": "#item_option_color",
#         "item_option_data": {
#           "name": "COLOR_OPTIONS",
#           "values": [
#             {
#               "type": "ITEM_OPTION_VAL",
#               "id": "#item_option_value_color_red",
#               "item_option_value_data": {
#                 "name": "RED"
#               }
#             },
#             {
#               "type": "ITEM_OPTION_VAL",
#               "id": "#item_option_value_color_blue",
#               "item_option_value_data": {
#                 "name": "Blue"
#               }
#             }
#           ]
#         }
#       },
#       {
#         "type": "ITEM_OPTION",
#         "id": "#item_option_size",
#         "item_option_data": {
#           "name": "SIZE_OPTIONS",
#           "values": [
#             {
#               "type": "ITEM_OPTION_VAL",
#               "id": "#item_option_value_size_small",
#               "item_option_value_data": {
#                 "name": "Small"
#               }
#             },
#             {
#               "type": "ITEM_OPTION_VAL",
#               "id": "#item_option_value_size_medium",
#               "item_option_value_data": {
#                 "name": "Medium"
#               }
#             },
#             {
#               "type": "ITEM_OPTION_VAL",
#               "id": "#item_option_value_size_large",
#               "item_option_value_data": {
#                 "name": "Large"
#               }
#             }
#           ]
#         }
#       },
      {
        "type": "ITEM",
        "id": "#item",
        "item_data": {
          "name": "Shirt",
          "variations": [
            {
              "type": "ITEM_VARIATION",
              "id": "#item_variation_small_red",
              "item_variation_data": {
                  "name": "item_variation_small_red",
                "pricing_type": "FIXED_PRICING",
                "price_money": {
                  "amount": 2500,
                  "currency": "USD"
                },
                "item_option_values": [
                  {
                    "item_option_id": "OIGNZFFYOOTUJL43ENK36H2I",
                    "item_option_value_id": "K6XJK5RW7UAI56D4MSZRR5M2"
                  },
#                   {
#                     "item_option_id": "#item_option_color",
#                     "item_option_value_id": "#item_option_value_color_red"
#                   }
                ]
              }
            },
#             {
#               "type": "ITEM_VARIATION",
#               "id": "#item_variation_medium_red",
#               "item_variation_data": {
#                 "pricing_type": "FIXED_PRICING",
#                 "price_money": {
#                   "amount": 3000,
#                   "currency": "USD"
#                 },
#                 "item_option_values": [
#                   {
#                     "item_option_id": "#item_option_size",
#                     "item_option_value_id": "#item_option_value_size_medium"
#                   },
#                   {
#                     "item_option_id": "#item_option_color",
#                     "item_option_value_id": "#item_option_value_color_red"
#                   }
#                 ]
#               }
#             },
#             {
#               "type": "ITEM_VARIATION",
#               "id": "#item_variation_large_red",
#               "item_variation_data": {
#                 "pricing_type": "FIXED_PRICING",
#                 "price_money": {
#                   "amount": 3500,
#                   "currency": "USD"
#                 },
#                 "item_option_values": [
#                   {
#                     "item_option_id": "#item_option_size",
#                     "item_option_value_id": "#item_option_value_size_large"
#                   },
#                   {
#                     "item_option_id": "#item_option_color",
#                     "item_option_value_id": "#item_option_value_color_red"
#                   }
#                 ]
#               }
#             },
#             {
#               "type": "ITEM_VARIATION",
#               "id": "#item_variation_small_blue",
#               "item_variation_data": {
#                 "pricing_type": "FIXED_PRICING",
#                 "price_money": {
#                   "amount": 2500,
#                   "currency": "USD"
#                 },
#                 "item_option_values": [
#                   {
#                     "item_option_id": "#item_option_size",
#                     "item_option_value_id": "#item_option_value_size_small"
#                   },
#                   {
#                     "item_option_id": "#item_option_color",
#                     "item_option_value_id": "#item_option_value_color_blue"
#                   }
#                 ]
#               }
#             },
#             {
#               "type": "ITEM_VARIATION",
#               "id": "#item_variation_medium_blue",
#               "item_variation_data": {
#                 "pricing_type": "FIXED_PRICING",
#                 "price_money": {
#                   "amount": 3000,
#                   "currency": "USD"
#                 },
#                 "item_option_values": [
#                   {
#                     "item_option_id": "#item_option_size",
#                     "item_option_value_id": "#item_option_value_size_medium"
#                   },
#                   {
#                     "item_option_id": "#item_option_color",
#                     "item_option_value_id": "#item_option_value_color_blue"
#                   }
#                 ]
#               }
#             },
#             {
#               "type": "ITEM_VARIATION",
#               "id": "#item_variation_large_blue",
#               "item_variation_data": {
#                 "pricing_type": "FIXED_PRICING",
#                 "price_money": {
#                   "amount": 3500,
#                   "currency": "USD"
#                 },
#                 "item_option_values": [
#                   {
#                     "item_option_id": "#item_option_size",
#                     "item_option_value_id": "#item_option_value_size_large"
#                   },
#                   {
#                     "item_option_id": "#item_option_color",
#                     "item_option_value_id": "#item_option_value_color_blue"
#                   }
#                 ]
#               }
#             }
          ],
          "product_type": "REGULAR",
          "item_options": [
            {
              "item_option_id": "#item_option_size"
            },
            {
              "item_option_id": "#item_option_color"
            }
          ]
        }
      }
    ]
  }
]
}
    
result = client.catalog.batch_upsert_catalog_objects(body)

if result.is_success():
  print(result.body)
elif result.is_error():
  print(result.errors)
# Out:
# [{'category': 'INVALID_REQUEST_ERROR', 'code': 'INVALID_VALUE', 'detail': 'Invalid object: Invalid Object with Id: #item_variation_small_red\n[merchant_token=ML3JGYDQZ76YY] Missing Item Option Value "#item_option_value_size_small".'}]
